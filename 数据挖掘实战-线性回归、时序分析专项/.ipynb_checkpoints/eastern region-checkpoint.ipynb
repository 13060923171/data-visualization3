# %%
import pandas as pd
import numpy as np

# %%
region = pd.read_excel('data.xlsx',sheet_name='eastern region')
region = region.dropna(how='any',axis=0)

# %%
region
# Out:
#     Unnamed: 0  CO2 emissions  population(万人)    GDP(亿元)  工业产值占比%  per human capital (yuan/person)    FDI（亿美元）  coal consumpution growth ratio
# 1         1998        1222.46         41907.0    42983.5  0.47724                           120887   370.01000                         0.00403
# 2         1999        1262.36         42223.0    46410.0  0.47275                           130129   363.64000                         0.01776
# 3         2000        1307.77         44502.0    52408.0  0.47308                           143824   366.82000                         0.02317
# 4         2001        1413.38         44859.0    58178.4  0.46672                           156099   404.51000                         0.06699
# 5         2002        1535.07         45263.0    65202.8  0.46642                           172721   492.35000                         0.09605
# 6         2003        1770.78         45718.0    75455.5  0.48478                           197549   602.43000                         0.14477
# 7         2004        2067.11         46247.0    89350.2  0.49699                           228899   572.13000                         0.15286
# 8         2005        2431.21         46728.0   104639.4  0.50058                           260397   647.73000                         0.21976
# 9         2006        2623.86         47438.0   122535.7  0.50224                           296306   765.70000                         0.09423
# 10        2007        2774.43         48160.0   149264.2  0.49652                           351532   903.27000                         0.10602
# 11        2008        2973.22         48854.0   174179.5  0.49476                           398264  1008.76000                         0.03827
# 12        2009        3159.49         49548.0   190009.1  0.48084                           424124   987.60000                         0.03066
# 13        2010        3482.70         50665.0   223387.7  0.48023                           485325  1084.09000                         0.07632
# 14        2011        3790.70         51641.0   259908.9  0.47456                           549139  1218.72000                         0.10643
# 15        2012        3810.51         52422.0   283480.2  0.46272                           588970  1367.57320                         0.00298
# 16        2013        3796.35         53068.0   310695.1  0.45018                           635889  1434.93360                        -0.02221
# 17        2014        3802.40         53739.0   336238.2  0.44403                           679023  1475.14100                        -0.01861
# 18        2015        3885.14         54203.0   364282.5  0.42869                           721961  1533.27640                        -0.00790
# 19        2016        3893.37         54787.0   396109.7  0.41201                           780080  1417.02380                        -0.01319
# 20        2017        3875.84         55283.0  4337173.0  0.04082                           855806  1551.18640                        -0.02418
# 21        2018        4097.62         55706.0   476378.3  0.39850                           932855  1425.96247                         0.03963
# 22        2019        4172.74         56074.0   509770.4  0.38586                           992596  1304.07890                        -0.01021

# %%
data = region.drop(['Unnamed: 0'],axis=1)
data
# Out:
#     CO2 emissions  population(万人)    GDP(亿元)  工业产值占比%  per human capital (yuan/person)    FDI（亿美元）  coal consumpution growth ratio
# 1         1222.46         41907.0    42983.5  0.47724                           120887   370.01000                         0.00403
# 2         1262.36         42223.0    46410.0  0.47275                           130129   363.64000                         0.01776
# 3         1307.77         44502.0    52408.0  0.47308                           143824   366.82000                         0.02317
# 4         1413.38         44859.0    58178.4  0.46672                           156099   404.51000                         0.06699
# 5         1535.07         45263.0    65202.8  0.46642                           172721   492.35000                         0.09605
# 6         1770.78         45718.0    75455.5  0.48478                           197549   602.43000                         0.14477
# 7         2067.11         46247.0    89350.2  0.49699                           228899   572.13000                         0.15286
# 8         2431.21         46728.0   104639.4  0.50058                           260397   647.73000                         0.21976
# 9         2623.86         47438.0   122535.7  0.50224                           296306   765.70000                         0.09423
# 10        2774.43         48160.0   149264.2  0.49652                           351532   903.27000                         0.10602
# 11        2973.22         48854.0   174179.5  0.49476                           398264  1008.76000                         0.03827
# 12        3159.49         49548.0   190009.1  0.48084                           424124   987.60000                         0.03066
# 13        3482.70         50665.0   223387.7  0.48023                           485325  1084.09000                         0.07632
# 14        3790.70         51641.0   259908.9  0.47456                           549139  1218.72000                         0.10643
# 15        3810.51         52422.0   283480.2  0.46272                           588970  1367.57320                         0.00298
# 16        3796.35         53068.0   310695.1  0.45018                           635889  1434.93360                        -0.02221
# 17        3802.40         53739.0   336238.2  0.44403                           679023  1475.14100                        -0.01861
# 18        3885.14         54203.0   364282.5  0.42869                           721961  1533.27640                        -0.00790
# 19        3893.37         54787.0   396109.7  0.41201                           780080  1417.02380                        -0.01319
# 20        3875.84         55283.0  4337173.0  0.04082                           855806  1551.18640                        -0.02418
# 21        4097.62         55706.0   476378.3  0.39850                           932855  1425.96247                         0.03963
# 22        4172.74         56074.0   509770.4  0.38586                           992596  1304.07890                        -0.01021

# %%
data['CO2 emissions'] = data['CO2 emissions'].apply(np.log)
data['population(万人)'] = data['population(万人)'].apply(np.log)
data['GDP(亿元)'] = data['GDP(亿元)'].apply(np.log)
data['工业产值占比%'] = data['工业产值占比%'].apply(np.log)
data['per human capital (yuan/person)'] = data['per human capital (yuan/person)'].apply(np.log)
data['FDI（亿美元）'] = data['FDI（亿美元）'].apply(np.log)
# data['coal consumpution growth ratio'] = data['coal consumpution growth ratio'].apply(np.log)

# %%
 data.describe()
# Out:
#        CO2 emissions  population(万人)   GDP(亿元)   工业产值占比%  per human capital (yuan/person)  FDI（亿美元）  coal consumpution growth ratio
# count       22.00000        22.00000  22.00000  22.00000                         22.00000  22.00000                        22.00000
# mean         7.87984        10.80578  12.10385  -0.88028                         12.82983   6.75696                         0.05107
# std          0.43903         0.09159   1.06450   0.52294                          0.69098   0.52536                         0.06649
# min          7.10862        10.64321  10.66857  -3.19862                         11.70261   5.89616                        -0.02418
# 25%          7.51786        10.73312  11.27355  -0.80843                         12.23057   6.36227                        -0.00518
# 50%          8.02778        10.80364  12.11133  -0.74884                         12.92633   6.90588                         0.03447
# 75%          8.24499        10.88875  12.70582  -0.72609                         13.41200   7.24743                         0.09559
# max          8.33633        10.93443  15.28273  -0.68868                         13.80808   7.34678                         0.21976

# %%
 data.corr()
# Out:
#                                  CO2 emissions  population(万人)  GDP(亿元)  工业产值占比%  per human capital (yuan/person)  FDI（亿美元）  coal consumpution growth ratio
# CO2 emissions                          1.00000         0.95339  0.84350 -0.25880                          0.97516   0.98457                        -0.30226
# population(万人)                         0.95339         1.00000  0.89575 -0.36986                          0.99191   0.96275                        -0.44268
# GDP(亿元)                                0.84350         0.89575  1.00000 -0.72866                          0.89661   0.87191                        -0.45400
# 工业产值占比%                               -0.25880        -0.36986 -0.72866  1.00000                         -0.35376  -0.31834                         0.33299
# per human capital (yuan/person)        0.97516         0.99191  0.89661 -0.35376                          1.00000   0.97721                        -0.42956
# FDI（亿美元）                               0.98457         0.96275  0.87191 -0.31834                          0.97721   1.00000                        -0.39393
# coal consumpution growth ratio        -0.30226        -0.44268 -0.45400  0.33299                         -0.42956  -0.39393                         1.00000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.subplots(figsize = (15,8))
sns.heatmap( data.corr(), annot=True,cmap="PiYG")
plt.title("Correlations Among Features", fontsize = 20)
# 保存图片
plt.savefig('./region/热力图.png')
plt.show()

# %%
#最小二乘法的求解过程

# %%
# standard import
import logging
import os

import numpy


# 样本x
SAMPLE_X = np.array(data['GDP(亿元)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('GDP与CO2线性关系')
# 保存图片
plt.savefig('./region/GDP与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['population(万人)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('population与CO2线性关系')
# 保存图片
plt.savefig('./region/population与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['工业产值占比%'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('工业产值与CO2线性关系')
# 保存图片
plt.savefig('./region/工业产值与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['per human capital (yuan/person)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('capital与CO2线性关系')
# 保存图片
plt.savefig('./region/capital与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['FDI（亿美元）'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('FDI与CO2线性关系')
# 保存图片
plt.savefig('./region/FDI与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['coal consumpution growth ratio'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('ratio与CO2线性关系')
# 保存图片
plt.savefig('./region/ratio与CO2线性关系.png')
# 显示图片
plt.show()

# %%
import numpy as np
from atrader import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import r2_score
set_setting('ALLOW_CONSOLE_SYSTEM_WARN', False)
import statsmodels.api as sm

# %%
train_x = data[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']]
train_y = data['CO2 emissions']

#分割数据，将25%的数据作为测试集，其余作为训练集
train_x,test_x,train_y,test_y = train_test_split(train_x,train_y,test_size=0.3)

# %%
#线性回归多因子 CO2预测

# %%
def co2_predict():
    # 获取各因子数据
    x1 = data['population(万人)']
    x2 = data['GDP(亿元)']
    x3 = data['工业产值占比%']
    x4 = data['per human capital (yuan/person)']
    x5 = data['FDI（亿美元）']
    x6 = data['coal consumpution growth ratio']
    y1 = data['CO2 emissions']

    # 以图的方式展示单个因子与co2的关系
    fig = plt.figure(figsize=(20,5))
    ax1 = plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=1)
    ax1.scatter(x1,y1,label='population')

    ax2 = plt.subplot2grid((6,2),(0,1),rowspan=2,colspan=1)
    ax2.scatter(x2,y1,label='GDP')

    ax3 = plt.subplot2grid((6,2),(2,0),rowspan=2,colspan=1)
    ax3.scatter(x3,y1,label='工业产值')
    
    ax4 = plt.subplot2grid((6,2),(2,1),rowspan=2,colspan=1)
    ax4.scatter(x4,y1,label='capital')
    
    ax5 = plt.subplot2grid((6,2),(4,0),rowspan=2,colspan=1)
    ax5.scatter(x5,y1,label='FDI')
    
    ax6 = plt.subplot2grid((6,2),(4,1),rowspan=2,colspan=1)
    ax6.scatter(x6,y1,label='ratio')
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    ax5.legend()
    ax6.legend()
    plt.savefig("./region/各因子与co2的回归关系")
    plt.show()
    
    # 创建模型
    model = LinearRegression()
    # 模型训练

    model.fit(train_x,train_y)
    # 模型预测
    predict_y = model.predict(test_x)
    #算出它的正确率
    score = r2_score(test_y, predict_y)
    print('多因子线性回归预测正确率:',score)

# %%
co2_predict()
# Out:
# 多因子线性回归预测正确率: 0.9835708082644202

# %%
data1 = region
data1['index'] = range(1, len(data1) + 1)  
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22 non-null     int64
#  1   CO2 emissions                    22 non-null     float64
#  2   population(万人)                   22 non-null     float64
#  3   GDP(亿元)                          22 non-null     float64
#  4   工业产值占比%                          22 non-null     float64
#  5   per human capital (yuan/person)  22 non-null     int64
#  6   FDI（亿美元）                         22 non-null     float64
#  7   coal consumpution growth ratio   22 non-null     float64
#  8   index                            22 non-null     int32
# dtypes: float64(6), int32(1), int64(2)
# memory usage: 1.6 KB

# %%
data1 = data1.set_index(['index','Unnamed: 0'])
train = data1[['GDP(亿元)','per human capital (yuan/person)','FDI（亿美元）']]
target =  data1['CO2 emissions'].apply(np.log)

# %%
data1['GDP(亿元)'] = data1['GDP(亿元)'].apply(np.log)
data1['per human capital (yuan/person)'] = data1['per human capital (yuan/person)'].apply(np.log)
data1['FDI（亿美元）'] = data1['FDI（亿美元）'].apply(np.log)

# %%
#混合最小二乘
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
#计算回归面板数据
exog = sm.add_constant(data1[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']])
mod = PooledOLS(target, exog)
#模型训练
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:          CO2 emissions   R-squared:                        0.9982
# Estimator:                  PooledOLS   R-squared (Between):              0.9982
# No. Observations:                  22   R-squared (Within):               0.0000
# Date:                Mon, Jul 25 2022   R-squared (Overall):              0.9982
# Time:                        23:44:52   Log-likelihood                    57.013
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1397.6
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(6,15)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             1397.6
#                                         P-value                           0.0000
# Time periods:                      22   Distribution:                    F(6,15)
# Avg Obs:                       1.0000
# Min Obs:                       1.0000
# Max Obs:                       1.0000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# const                              -1.7137     0.3705    -4.6250     0.0003     -2.5035     -0.9239
# population(万人)                  -6.896e-06   1.16e-05    -0.5946     0.5610  -3.162e-05   1.782e-05
# GDP(亿元)                             0.5077     0.0779     6.5171     0.0000      0.3416      0.6737
# 工业产值占比%                             3.2845     0.4681     7.0171     0.0000      2.2868      4.2822
# per human capital (yuan/person)     0.1763     0.1142     1.5438     0.1435     -0.0671      0.4197
# FDI（亿美元）                            0.0085     0.0738     0.1147     0.9102     -0.1488      0.1657
# coal consumpution growth ratio      0.1887     0.1039     1.8163     0.0894     -0.0328      0.4102
# ===================================================================================================

# %%
data2 = region
data2 = data2.set_index(['Unnamed: 0'])
data2
# Out:
#             CO2 emissions  population(万人)    GDP(亿元)  工业产值占比%  per human capital (yuan/person)    FDI（亿美元）  coal consumpution growth ratio  index
# Unnamed: 0
# 1998              1222.46         41907.0    42983.5  0.47724                           120887   370.01000                         0.00403      1
# 1999              1262.36         42223.0    46410.0  0.47275                           130129   363.64000                         0.01776      2
# 2000              1307.77         44502.0    52408.0  0.47308                           143824   366.82000                         0.02317      3
# 2001              1413.38         44859.0    58178.4  0.46672                           156099   404.51000                         0.06699      4
# 2002              1535.07         45263.0    65202.8  0.46642                           172721   492.35000                         0.09605      5
# 2003              1770.78         45718.0    75455.5  0.48478                           197549   602.43000                         0.14477      6
# 2004              2067.11         46247.0    89350.2  0.49699                           228899   572.13000                         0.15286      7
# 2005              2431.21         46728.0   104639.4  0.50058                           260397   647.73000                         0.21976      8
# 2006              2623.86         47438.0   122535.7  0.50224                           296306   765.70000                         0.09423      9
# 2007              2774.43         48160.0   149264.2  0.49652                           351532   903.27000                         0.10602     10
# 2008              2973.22         48854.0   174179.5  0.49476                           398264  1008.76000                         0.03827     11
# 2009              3159.49         49548.0   190009.1  0.48084                           424124   987.60000                         0.03066     12
# 2010              3482.70         50665.0   223387.7  0.48023                           485325  1084.09000                         0.07632     13
# 2011              3790.70         51641.0   259908.9  0.47456                           549139  1218.72000                         0.10643     14
# 2012              3810.51         52422.0   283480.2  0.46272                           588970  1367.57320                         0.00298     15
# 2013              3796.35         53068.0   310695.1  0.45018                           635889  1434.93360                        -0.02221     16
# 2014              3802.40         53739.0   336238.2  0.44403                           679023  1475.14100                        -0.01861     17
# 2015              3885.14         54203.0   364282.5  0.42869                           721961  1533.27640                        -0.00790     18
# 2016              3893.37         54787.0   396109.7  0.41201                           780080  1417.02380                        -0.01319     19
# 2017              3875.84         55283.0  4337173.0  0.04082                           855806  1551.18640                        -0.02418     20
# 2018              4097.62         55706.0   476378.3  0.39850                           932855  1425.96247                         0.03963     21
# 2019              4172.74         56074.0   509770.4  0.38586                           992596  1304.07890                        -0.01021     22

# %%
#导入对应的acf和pacf
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
#导入时间模型
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
#导入画图库
import matplotlib.pyplot as plt

# %%
#测试数据
d1 = data2['CO2 emissions'].apply(np.log)
#原始数据之后的时间趋势
plt.figure(figsize=(12,8),dpi=300)
plt.plot(d1)
plt.title('CO2时间变化趋势')
plt.savefig('./region/CO2时间变化趋势.png')
plt.show()

# %%
#由于上图不是很平稳，所以对该时间进行时间序列的差分，找出合适的差分次数
plt.figure(figsize=(12,8),dpi=300)
#这个是一阶差分，可以看出时间序列的均值和方差基本平稳
diff1 = d1.diff(1)
plt.plot(diff1)
plt.title('一阶差分时间变化趋势')
plt.savefig('./region/一阶差分时间变化趋势.png')
plt.show()

# %%
#格兰杰因果检验
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CO2 emissions                    22 non-null     float64
#  1   population(万人)                   22 non-null     float64
#  2   GDP(亿元)                          22 non-null     float64
#  3   工业产值占比%                          22 non-null     float64
#  4   per human capital (yuan/person)  22 non-null     float64
#  5   FDI（亿美元）                         22 non-null     float64
#  6   coal consumpution growth ratio   22 non-null     float64
# dtypes: float64(7)
# memory usage: 1.4 KB

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.5438  , p=0.0063  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=11.1345 , p=0.0008  , df=1
# likelihood ratio test: chi2=8.9335  , p=0.0028  , df=1
# parameter F test:         F=9.5438  , p=0.0063  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8509  , p=0.0893  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=7.6025  , p=0.0223  , df=2
# likelihood ratio test: chi2=6.4435  , p=0.0399  , df=2
# parameter F test:         F=2.8509  , p=0.0893  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (9.543817946181688, 0.00632551266904242, 18.0, 1),
#    'ssr_chi2test': (11.134454270545302, 0.0008473885747879272, 1),
#    'lrtest': (8.933533529648045, 0.002799821687688674, 1),
#    'params_ftest': (9.543817946181688, 0.00632551266904242, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51ea7e08>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e52cf21c8>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.8509289331779533, 0.08925129456064983, 15.0, 2),
#    'ssr_chi2test': (7.602477155141209, 0.022343081072039486, 2),
#    'lrtest': (6.443464942790271, 0.03988589719221136, 2),
#    'params_ftest': (2.8509289331779386, 0.08925129456065085, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4ff22ac8>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4ff22308>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'population(万人)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0650  , p=0.1679  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=2.4091  , p=0.1206  , df=1
# likelihood ratio test: chi2=2.2807  , p=0.1310  , df=1
# parameter F test:         F=2.0650  , p=0.1679  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.4234  , p=0.0169  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=14.4624 , p=0.0007  , df=2
# likelihood ratio test: chi2=10.8827 , p=0.0043  , df=2
# parameter F test:         F=5.4234  , p=0.0169  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.0649558102226333, 0.16787495649459144, 18.0, 1),
#    'ssr_chi2test': (2.409115111926406, 0.12063053728606023, 1),
#    'lrtest': (2.280663913268995, 0.1309957876679766, 1),
#    'params_ftest': (2.0649558102235224, 0.1678749564945047, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e52ddf308>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4fd83c48>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (5.423390096765075, 0.01689024975903716, 15.0, 2),
#    'ssr_chi2test': (14.462373591373535, 0.0007236615149507245, 2),
#    'lrtest': (10.882716695681552, 0.004333592744605455, 2),
#    'params_ftest': (5.423390096761663, 0.0168902497590706, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51b6d708>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51b6dd08>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.5438  , p=0.0063  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=11.1345 , p=0.0008  , df=1
# likelihood ratio test: chi2=8.9335  , p=0.0028  , df=1
# parameter F test:         F=9.5438  , p=0.0063  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8509  , p=0.0893  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=7.6025  , p=0.0223  , df=2
# likelihood ratio test: chi2=6.4435  , p=0.0399  , df=2
# parameter F test:         F=2.8509  , p=0.0893  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (9.543817946181688, 0.00632551266904242, 18.0, 1),
#    'ssr_chi2test': (11.134454270545302, 0.0008473885747879272, 1),
#    'lrtest': (8.933533529648045, 0.002799821687688674, 1),
#    'params_ftest': (9.543817946181688, 0.00632551266904242, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51b6dbc8>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f22a748>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.8509289331779533, 0.08925129456064983, 15.0, 2),
#    'ssr_chi2test': (7.602477155141209, 0.022343081072039486, 2),
#    'lrtest': (6.443464942790271, 0.03988589719221136, 2),
#    'params_ftest': (2.8509289331779386, 0.08925129456065085, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51e5dc08>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4fcaa548>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ '工业产值占比%','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4583  , p=0.2428  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=1.7014  , p=0.1921  , df=1
# likelihood ratio test: chi2=1.6359  , p=0.2009  , df=1
# parameter F test:         F=1.4583  , p=0.2428  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2933  , p=0.3033  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.4487  , p=0.1783  , df=2
# likelihood ratio test: chi2=3.1816  , p=0.2038  , df=2
# parameter F test:         F=1.2933  , p=0.3033  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (1.4583050236897472, 0.24282876277351106, 18.0, 1),
#    'ssr_chi2test': (1.7013558609713715, 0.1921107554948869, 1),
#    'lrtest': (1.63594650530651, 0.20088253220033989, 1),
#    'params_ftest': (1.4583050236897372, 0.24282876277351292, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4fa94e88>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f00c6c8>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.2932515364930934, 0.30327614490407, 15.0, 2),
#    'ssr_chi2test': (3.4486707639815823, 0.17829150815162334, 2),
#    'lrtest': (3.181630717859381, 0.20375940693318562, 2),
#    'params_ftest': (1.293251536493118, 0.30327614490406346, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f8a76c8>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51c37548>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'per human capital (yuan/person)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.2080  , p=0.0349  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=6.0760  , p=0.0137  , df=1
# likelihood ratio test: chi2=5.3367  , p=0.0209  , df=1
# parameter F test:         F=5.2080  , p=0.0349  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2377  , p=0.3180  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.3006  , p=0.1920  , df=2
# likelihood ratio test: chi2=3.0550  , p=0.2171  , df=2
# parameter F test:         F=1.2377  , p=0.3180  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (5.208039996299723, 0.0348661548941468, 18.0, 1),
#    'ssr_chi2test': (6.076046662349677, 0.013702708476195133, 1),
#    'lrtest': (5.336667258418004, 0.0208813576052345, 1),
#    'params_ftest': (5.208039996298762, 0.03486615489416165, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f7ed688>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e51b7ba48>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.2377346914488305, 0.3180299870290225, 15.0, 2),
#    'ssr_chi2test': (3.300625843863548, 0.1919898213941474, 2),
#    'lrtest': (3.054958938171751, 0.21708214057153927, 2),
#    'params_ftest': (1.2377346914488045, 0.31802998702902996, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4fa874c8>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f7e6308>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'FDI（亿美元）','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.4864  , p=0.0065  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=11.0674 , p=0.0009  , df=1
# likelihood ratio test: chi2=8.8897  , p=0.0029  , df=1
# parameter F test:         F=9.4864  , p=0.0065  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.5218  , p=0.0160  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=14.7248 , p=0.0006  , df=2
# likelihood ratio test: chi2=11.0344 , p=0.0040  , df=2
# parameter F test:         F=5.5218  , p=0.0160  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (9.48636381382125, 0.006455580944054792, 18.0, 1),
#    'ssr_chi2test': (11.067424449458125, 0.0008785763495682348, 1),
#    'lrtest': (8.889683512098742, 0.0028678643916784617, 1),
#    'params_ftest': (9.486363813821013, 0.006455580944055336, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4fd82308>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e50070648>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (5.521792932037751, 0.01595616752778472, 15.0, 2),
#    'ssr_chi2test': (14.724781152100668, 0.0006346793951807454, 2),
#    'lrtest': (11.034426255024812, 0.004017027299996685, 2),
#    'params_ftest': (5.521792932037592, 0.015956167527786197, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f203548>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f203308>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'coal consumpution growth ratio','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.3903  , p=0.0506  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=5.1221  , p=0.0236  , df=1
# likelihood ratio test: chi2=4.5834  , p=0.0323  , df=1
# parameter F test:         F=4.3903  , p=0.0506  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.7894  , p=0.0030  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=23.4384 , p=0.0000  , df=2
# likelihood ratio test: chi2=15.5122 , p=0.0004  , df=2
# parameter F test:         F=8.7894  , p=0.0030  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (4.390342965085721, 0.050552114211510825, 18.0, 1),
#    'ssr_chi2test': (5.122066792600008, 0.023623464612434416, 1),
#    'lrtest': (4.583417797912887, 0.032282762711355106, 1),
#    'params_ftest': (4.390342965085724, 0.050552114211510825, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f200d88>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f2004c8>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (8.789403314170244, 0.00297625853259304, 15.0, 2),
#    'ssr_chi2test': (23.438408837787314, 8.1360608601466e-06, 2),
#    'lrtest': (15.51223544872903, 0.000428115420631884, 2),
#    'params_ftest': (8.789403314170585, 0.002976258532592572, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f845d88>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x26e4f227948>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
#主要看p值（第二列），所有的p小于0.05才能证明b对a有效

# number of lags (no zero) 1：当lags为1时的检测结果
# ssr based F test：残差平方和F检验
# ssr based chi2 test：残差平方和卡方检验
# likelihood ratio test：似然比检验结果
# parr F testamete：参数 F 检验结果

# %%
from statsmodels.tsa.stattools import adfuller
adf_seq = np.array(data['CO2 emissions'])
dftest = adfuller(adf_seq,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
# Out:
# Test Statistic                 -1.81424
# p-value                         0.37342
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# dtype: float64
# Test Statistic                 -1.81424
# p-value                         0.37342
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# Critical Value (5%)            -3.15497
# dtype: float64
# Test Statistic                 -1.81424
# p-value                         0.37342
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# Critical Value (5%)            -3.15497
# Critical Value (10%)           -2.71448
# dtype: float64

# %% [markdown]
# # Test Statistic : T值，表示T统计量
#
# p-value： p值，表示T统计量对应的概率值
#
# Lags Used：表示延迟
#
# Number of Observations Used: 表示测试的次数
#
# Critical Value 1% : 表示t值下小于 – 4.938690 ， 则原假设发生的概率小于1%， 其它的数值以此类推。
#
# 其中t值和p值是最重要的，其实这两个值是等效的，既可以看t值也可以看p值。
#
# p值越小越好，要求小于给定的显著水平，p值小于0.05，等于0最好。
#
# t值，ADF值要小于t值，1%， 5%， 10% 的三个level，都是一个临界值，如果小于这个临界值，说明拒绝原假设。
#
# 其中，1% ： 严格拒绝原假设； 5%： 拒绝原假设； 10% 以此类推，程度越来越低。如果，ADF小于1% level， 说明严格拒绝原假设
