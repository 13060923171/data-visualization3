# %%
import pandas as pd
import numpy as np

# %%
centre = pd.read_excel('data.xlsx',sheet_name='centre')
centre = centre.dropna(how='any',axis=0)

# %%
centre
# Out:
#     Unnamed: 0  CO2 emissions  population(万人)   GDP(亿元)   工业产值占比%  \
# 1         1998         741.53         35271.0   16490.4  0.396691
# 2         1999         646.67         35529.0   17390.3  0.395968
# 3         2000         606.13         35185.0   19124.0  0.398970
# 4         2001         640.27         35395.0   20953.4  0.404712
# 5         2002         789.42         35574.0   23002.8  0.414423
# 6         2003        1013.52         35746.0   26334.7  0.431116
# 7         2004        1094.16         35960.0   31523.8  0.436902
# 8         2005        1236.82         35202.0   36779.6  0.458757
# 9         2006        1340.60         35251.0   42852.0  0.476239
# 10        2007        1350.67         35293.0   53216.2  0.485279
# 11        2008        1690.92         35466.0   64215.7  0.494457
# 12        2009        1896.87         35603.0   70788.2  0.490864
# 13        2010        2155.58         35696.0   85993.1  0.509171
# 14        2011        2471.79         35810.0  103940.0  0.519036
# 15        2012        2489.60         35904.0  115592.5  0.511416
# 16        2013        3162.10         35970.0  127427.1  0.497030
# 17        2014        3184.56         36077.0  138980.4  0.486197
# 18        2015        3078.21         36181.0  148415.2  0.462276
# 19        2016        3046.29         36331.0  161098.5  0.445811
# 20        2017        3197.96         36444.0  180259.3  0.437565
# 21        2018        3225.47         36507.0  200973.1  0.421781
# 22        2019        3273.61         36573.0  217515.3  0.415681
#
#     per human capital (yuan/person)  FDI（亿美元）  Coal consumption growth ratio
# 1                             28341   43.6700                       0.023489
# 2                             29668   31.3700                      -0.052999
# 3                             32881   29.3600                       0.028710
# 4                             36124   33.4600                       0.063205
# 5                             39807   45.9600                       0.116948
# 6                             45619   58.3000                       0.130756
# 7                             54551   70.5200                       0.155495
# 8                             63080   88.7300                       0.172273
# 9                             73201  115.6000                       0.104463
# 10                            90831  165.4500                       0.076627
# 11                           109375  194.0000                       0.012590
# 12                           119238  214.5600                       0.031722
# 13                           144804  263.1000                       0.089589
# 14                           175151  356.4800                       0.118205
# 15                           194034  430.3023                      -0.026829
# 16                           212855  500.9523                      -0.010762
# 17                           230614  568.6303                      -0.001074
# 18                           244235  625.6130                      -0.007194
# 19                           263384  675.1420                      -0.016707
# 20                           295134  717.4383                       0.078956
# 21                           328501  779.6940                       0.037021
# 22                           354842  826.1178                       0.005591

# %%
centre['coal consumpution growth ratio'] = centre['Coal consumption growth ratio']
data = centre.drop(['Coal consumption growth ratio','Unnamed: 0'],axis=1)
data
# Out:
#     CO2 emissions  population(万人)   GDP(亿元)   工业产值占比%  \
# 1          741.53         35271.0   16490.4  0.396691
# 2          646.67         35529.0   17390.3  0.395968
# 3          606.13         35185.0   19124.0  0.398970
# 4          640.27         35395.0   20953.4  0.404712
# 5          789.42         35574.0   23002.8  0.414423
# 6         1013.52         35746.0   26334.7  0.431116
# 7         1094.16         35960.0   31523.8  0.436902
# 8         1236.82         35202.0   36779.6  0.458757
# 9         1340.60         35251.0   42852.0  0.476239
# 10        1350.67         35293.0   53216.2  0.485279
# 11        1690.92         35466.0   64215.7  0.494457
# 12        1896.87         35603.0   70788.2  0.490864
# 13        2155.58         35696.0   85993.1  0.509171
# 14        2471.79         35810.0  103940.0  0.519036
# 15        2489.60         35904.0  115592.5  0.511416
# 16        3162.10         35970.0  127427.1  0.497030
# 17        3184.56         36077.0  138980.4  0.486197
# 18        3078.21         36181.0  148415.2  0.462276
# 19        3046.29         36331.0  161098.5  0.445811
# 20        3197.96         36444.0  180259.3  0.437565
# 21        3225.47         36507.0  200973.1  0.421781
# 22        3273.61         36573.0  217515.3  0.415681
#
#     per human capital (yuan/person)  FDI（亿美元）  coal consumpution growth ratio
# 1                             28341   43.6700                        0.023489
# 2                             29668   31.3700                       -0.052999
# 3                             32881   29.3600                        0.028710
# 4                             36124   33.4600                        0.063205
# 5                             39807   45.9600                        0.116948
# 6                             45619   58.3000                        0.130756
# 7                             54551   70.5200                        0.155495
# 8                             63080   88.7300                        0.172273
# 9                             73201  115.6000                        0.104463
# 10                            90831  165.4500                        0.076627
# 11                           109375  194.0000                        0.012590
# 12                           119238  214.5600                        0.031722
# 13                           144804  263.1000                        0.089589
# 14                           175151  356.4800                        0.118205
# 15                           194034  430.3023                       -0.026829
# 16                           212855  500.9523                       -0.010762
# 17                           230614  568.6303                       -0.001074
# 18                           244235  625.6130                       -0.007194
# 19                           263384  675.1420                       -0.016707
# 20                           295134  717.4383                        0.078956
# 21                           328501  779.6940                        0.037021
# 22                           354842  826.1178                        0.005591

# %%
data['CO2 emissions'] = data['CO2 emissions'].apply(np.log)
data['population(万人)'] = data['population(万人)'].apply(np.log)
data['GDP(亿元)'] = data['GDP(亿元)'].apply(np.log)
data['工业产值占比%'] = data['工业产值占比%'].apply(np.log)
data['per human capital (yuan/person)'] = data['per human capital (yuan/person)'].apply(np.log)
data['FDI（亿美元）'] = data['FDI（亿美元）'].apply(np.log)
# data['coal consumpution growth ratio'] = data['coal consumpution growth ratio'].apply(np.log)

# %%
 data.describe()
# Out:
#        CO2 emissions  population(万人)    GDP(亿元)    工业产值占比%  \
# count      22.000000       22.000000  22.000000  22.000000
# mean        7.399103       10.484828  11.037759  -0.793337
# std         0.614548        0.012312   0.879904   0.090650
# min         6.407094       10.468375   9.710534  -0.926422
# 25%         6.940324       10.474827  10.223607  -0.874196
# 50%         7.490494       10.483494  11.118725  -0.793547
# 75%         8.029498       10.492668  11.820391  -0.713976
# max         8.093649       10.507066  12.290024  -0.655782
#
#        per human capital (yuan/person)   FDI（亿美元）  \
# count                        22.000000  22.000000
# mean                         11.561212   5.191847
# std                           0.860871   1.182291
# min                          10.252065   3.379633
# 25%                          10.772783   4.113176
# 50%                          11.645707   5.318224
# 75%                          12.328467   6.311551
# max                          12.779428   6.716737
#
#        coal consumpution growth ratio
# count                       22.000000
# mean                         0.051367
# std                          0.063062
# min                         -0.052999
# 25%                          0.000592
# 50%                          0.034371
# 75%                          0.100745
# max                          0.172273

# %%
 data.corr()
# Out:
#                                  CO2 emissions  population(万人)   GDP(亿元)  \
# CO2 emissions                         1.000000        0.782363  0.985838
# population(万人)                        0.782363        1.000000  0.813669
# GDP(亿元)                               0.985838        0.813669  1.000000
# 工业产值占比%                               0.574441        0.036742  0.497541
# per human capital (yuan/person)       0.986427        0.811388  0.999957
# FDI（亿美元）                              0.992582        0.795665  0.994553
# coal consumpution growth ratio       -0.274870       -0.291770 -0.309262
#
#                                   工业产值占比%  per human capital (yuan/person)  \
# CO2 emissions                    0.574441                         0.986427
# population(万人)                   0.036742                         0.811388
# GDP(亿元)                          0.497541                         0.999957
# 工业产值占比%                          1.000000                         0.503754
# per human capital (yuan/person)  0.503754                         1.000000
# FDI（亿美元）                         0.523335                         0.994589
# coal consumpution growth ratio   0.043423                        -0.304123
#
#                                  FDI（亿美元）  coal consumpution growth ratio
# CO2 emissions                    0.992582                       -0.274870
# population(万人)                   0.795665                       -0.291770
# GDP(亿元)                          0.994553                       -0.309262
# 工业产值占比%                          0.523335                        0.043423
# per human capital (yuan/person)  0.994589                       -0.304123
# FDI（亿美元）                         1.000000                       -0.318450
# coal consumpution growth ratio  -0.318450                        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.subplots(figsize = (15,8))
sns.heatmap( data.corr(), annot=True,cmap="PiYG")
plt.title("Correlations Among Features", fontsize = 20)
# 保存图片
plt.savefig('./centre/热力图.png')
plt.show()

# %%
#最小二乘法的求解过程

# %%
# standard import
import logging
import os

import numpy


# 样本x
SAMPLE_X = np.array(data['GDP(亿元)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('GDP与CO2线性关系')
# 保存图片
plt.savefig('./centre/GDP与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['population(万人)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('population与CO2线性关系')
# 保存图片
plt.savefig('./centre/population与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['工业产值占比%'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('工业产值与CO2线性关系')
# 保存图片
plt.savefig('./centre/工业产值与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['per human capital (yuan/person)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('capital与CO2线性关系')
# 保存图片
plt.savefig('./centre/capital与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['FDI（亿美元）'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('FDI与CO2线性关系')
# 保存图片
plt.savefig('./centre/FDI与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['coal consumpution growth ratio'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('ratio与CO2线性关系')
# 保存图片
plt.savefig('./centre/ratio与CO2线性关系.png')
# 显示图片
plt.show()

# %%
import numpy as np
from atrader import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import r2_score
set_setting('ALLOW_CONSOLE_SYSTEM_WARN', False)
import statsmodels.api as sm

# %%
train_x = data[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']]
train_y = data['CO2 emissions']

#分割数据，将25%的数据作为测试集，其余作为训练集
train_x,test_x,train_y,test_y = train_test_split(train_x,train_y,test_size=0.3)

# %%
#线性回归多因子 CO2预测

# %%
def co2_predict():
    # 获取各因子数据
    x1 = data['population(万人)']
    x2 = data['GDP(亿元)']
    x3 = data['工业产值占比%']
    x4 = data['per human capital (yuan/person)']
    x5 = data['FDI（亿美元）']
    x6 = data['coal consumpution growth ratio']
    y1 = data['CO2 emissions']

    # 以图的方式展示单个因子与co2的关系
    fig = plt.figure(figsize=(20,5))
    ax1 = plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=1)
    ax1.scatter(x1,y1,label='population')

    ax2 = plt.subplot2grid((6,2),(0,1),rowspan=2,colspan=1)
    ax2.scatter(x2,y1,label='GDP')

    ax3 = plt.subplot2grid((6,2),(2,0),rowspan=2,colspan=1)
    ax3.scatter(x3,y1,label='工业产值')
    
    ax4 = plt.subplot2grid((6,2),(2,1),rowspan=2,colspan=1)
    ax4.scatter(x4,y1,label='capital')
    
    ax5 = plt.subplot2grid((6,2),(4,0),rowspan=2,colspan=1)
    ax5.scatter(x5,y1,label='FDI')
    
    ax6 = plt.subplot2grid((6,2),(4,1),rowspan=2,colspan=1)
    ax6.scatter(x6,y1,label='ratio')
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    ax5.legend()
    ax6.legend()
    plt.savefig("./centre/各因子与co2的回归关系")
    plt.show()
    
    # 创建模型
    model = LinearRegression()
    # 模型训练

    model.fit(train_x,train_y)
    # 模型预测
    predict_y = model.predict(test_x)
    #算出它的正确率
    score = r2_score(test_y, predict_y)
    print('多因子线性回归预测正确率:',score)

# %%
co2_predict()
# Out:
# 多因子线性回归预测正确率: 0.9563822445652881

# %%
data1 = centre
data1['index'] = range(1, len(data1) + 1)  
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22 non-null     int64
#  1   CO2 emissions                    22 non-null     float64
#  2   population(万人)                   22 non-null     float64
#  3   GDP(亿元)                          22 non-null     float64
#  4   工业产值占比%                          22 non-null     float64
#  5   per human capital (yuan/person)  22 non-null     int64
#  6   FDI（亿美元）                         22 non-null     float64
#  7   Coal consumption growth ratio    22 non-null     float64
#  8   coal consumpution growth ratio   22 non-null     float64
#  9   index                            22 non-null     int64
# dtypes: float64(7), int64(3)
# memory usage: 1.9 KB

# %%
data1 = data1.set_index(['index','Unnamed: 0'])
train = data1[['GDP(亿元)','per human capital (yuan/person)','FDI（亿美元）']]
target =  data1['CO2 emissions'].apply(np.log)

# %%
data1['GDP(亿元)'] = data1['GDP(亿元)'].apply(np.log)
data1['per human capital (yuan/person)'] = data1['per human capital (yuan/person)'].apply(np.log)
data1['FDI（亿美元）'] = data1['FDI（亿美元）'].apply(np.log)

# %%
#混合最小二乘
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
#计算回归面板数据
exog = sm.add_constant(data1[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']])
mod = PooledOLS(target, exog)
#模型训练
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:          CO2 emissions   R-squared:                        0.9928
# Estimator:                  PooledOLS   R-squared (Between):              0.9928
# No. Observations:                  22   R-squared (Within):               0.0000
# Date:                Tue, Jul 26 2022   R-squared (Overall):              0.9928
# Time:                        09:54:21   Log-likelihood                    34.350
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      347.05
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(6,15)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             347.05
#                                         P-value                           0.0000
# Time periods:                      22   Distribution:                    F(6,15)
# Avg Obs:                       1.0000
# Min Obs:                       1.0000
# Max Obs:                       1.0000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# const                               0.1523     3.2094     0.0475     0.9628     -6.6884      6.9931
# population(万人)                      0.0002  8.297e-05     2.3957     0.0301   2.192e-05      0.0004
# GDP(亿元)                             3.3329     3.6835     0.9048     0.3799     -4.5183      11.184
# 工业产值占比%                             2.6160     0.9482     2.7589     0.0146      0.5949      4.6370
# per human capital (yuan/person)    -3.4891     3.7537    -0.9295     0.3673     -11.490      4.5117
# FDI（亿美元）                            0.4772     0.1192     4.0042     0.0011      0.2232      0.7313
# coal consumpution growth ratio      0.4159     0.3067     1.3558     0.1952     -0.2379      1.0697
# ===================================================================================================
# E:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
data2 = centre
data2 = data2.set_index(['Unnamed: 0'])
data2
# Out:
#             CO2 emissions  population(万人)   GDP(亿元)  工业产值占比%  per human capital (yuan/person)  FDI（亿美元）  Coal consumption growth ratio  coal consumpution growth ratio  index
# Unnamed: 0
# 1998               741.53         35271.0   16490.4  0.39669                            28341   43.6700                        0.02349                         0.02349      1
# 1999               646.67         35529.0   17390.3  0.39597                            29668   31.3700                       -0.05300                        -0.05300      2
# 2000               606.13         35185.0   19124.0  0.39897                            32881   29.3600                        0.02871                         0.02871      3
# 2001               640.27         35395.0   20953.4  0.40471                            36124   33.4600                        0.06320                         0.06320      4
# 2002               789.42         35574.0   23002.8  0.41442                            39807   45.9600                        0.11695                         0.11695      5
# 2003              1013.52         35746.0   26334.7  0.43112                            45619   58.3000                        0.13076                         0.13076      6
# 2004              1094.16         35960.0   31523.8  0.43690                            54551   70.5200                        0.15549                         0.15549      7
# 2005              1236.82         35202.0   36779.6  0.45876                            63080   88.7300                        0.17227                         0.17227      8
# 2006              1340.60         35251.0   42852.0  0.47624                            73201  115.6000                        0.10446                         0.10446      9
# 2007              1350.67         35293.0   53216.2  0.48528                            90831  165.4500                        0.07663                         0.07663     10
# 2008              1690.92         35466.0   64215.7  0.49446                           109375  194.0000                        0.01259                         0.01259     11
# 2009              1896.87         35603.0   70788.2  0.49086                           119238  214.5600                        0.03172                         0.03172     12
# 2010              2155.58         35696.0   85993.1  0.50917                           144804  263.1000                        0.08959                         0.08959     13
# 2011              2471.79         35810.0  103940.0  0.51904                           175151  356.4800                        0.11821                         0.11821     14
# 2012              2489.60         35904.0  115592.5  0.51142                           194034  430.3023                       -0.02683                        -0.02683     15
# 2013              3162.10         35970.0  127427.1  0.49703                           212855  500.9523                       -0.01076                        -0.01076     16
# 2014              3184.56         36077.0  138980.4  0.48620                           230614  568.6303                       -0.00107                        -0.00107     17
# 2015              3078.21         36181.0  148415.2  0.46228                           244235  625.6130                       -0.00719                        -0.00719     18
# 2016              3046.29         36331.0  161098.5  0.44581                           263384  675.1420                       -0.01671                        -0.01671     19
# 2017              3197.96         36444.0  180259.3  0.43756                           295134  717.4383                        0.07896                         0.07896     20
# 2018              3225.47         36507.0  200973.1  0.42178                           328501  779.6940                        0.03702                         0.03702     21
# 2019              3273.61         36573.0  217515.3  0.41568                           354842  826.1178                        0.00559                         0.00559     22

# %%
#导入对应的acf和pacf
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
#导入时间模型
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
#导入画图库
import matplotlib.pyplot as plt

# %%
#测试数据
d1 = data2['CO2 emissions'].apply(np.log)
#原始数据之后的时间趋势
plt.figure(figsize=(12,8),dpi=300)
plt.plot(d1)
plt.title('CO2时间变化趋势')
plt.savefig('./centre/CO2时间变化趋势.png')
plt.show()

# %%
#由于上图不是很平稳，所以对该时间进行时间序列的差分，找出合适的差分次数
plt.figure(figsize=(12,8),dpi=300)
#这个是一阶差分，可以看出时间序列的均值和方差基本平稳
diff1 = d1.diff(1)
plt.plot(diff1)
plt.title('一阶差分时间变化趋势')
plt.savefig('./centre/一阶差分时间变化趋势.png')
plt.show()

# %%
#格兰杰因果检验
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CO2 emissions                    22 non-null     float64
#  1   population(万人)                   22 non-null     float64
#  2   GDP(亿元)                          22 non-null     float64
#  3   工业产值占比%                          22 non-null     float64
#  4   per human capital (yuan/person)  22 non-null     float64
#  5   FDI（亿美元）                         22 non-null     float64
#  6   coal consumpution growth ratio   22 non-null     float64
# dtypes: float64(7)
# memory usage: 1.4 KB

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5686  , p=0.4606  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=0.6633  , p=0.4154  , df=1
# likelihood ratio test: chi2=0.6531  , p=0.4190  , df=1
# parameter F test:         F=0.5686  , p=0.4606  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7673  , p=0.4817  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=2.0461  , p=0.3595  , df=2
# likelihood ratio test: chi2=1.9481  , p=0.3776  , df=2
# parameter F test:         F=0.7673  , p=0.4817  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (0.5685693968546055, 0.4605790756976246, 18.0, 1),
#    'ssr_chi2test': (0.6633309629970399, 0.4153864452952253, 1),
#    'lrtest': (0.6530700980527229, 0.4190171733073951, 1),
#    'params_ftest': (0.5685693968547763, 0.46057907569755774, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2921580>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2921490>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.7672844711279297, 0.48165698539078594, 15.0, 2),
#    'ssr_chi2test': (2.0460919230078125, 0.35949825294825305, 2),
#    'lrtest': (1.9480615115744229, 0.3775581222999371, 2),
#    'params_ftest': (0.7672844711282072, 0.4816569853906648, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d293ba60>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d293bb50>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'population(万人)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9428  , p=0.1034  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=3.4332  , p=0.0639  , df=1
# likelihood ratio test: chi2=3.1799  , p=0.0746  , df=1
# parameter F test:         F=2.9428  , p=0.1034  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5062  , p=0.2535  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=4.0165  , p=0.1342  , df=2
# likelihood ratio test: chi2=3.6602  , p=0.1604  , df=2
# parameter F test:         F=1.5062  , p=0.2535  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.9427682529963892, 0.10342545549640088, 18.0, 1),
#    'ssr_chi2test': (3.4332296284957877, 0.06389703283379465, 1),
#    'lrtest': (3.1798543999354365, 0.07455137260807915, 1),
#    'params_ftest': (2.94276825299818, 0.10342545549630358, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d1b483a0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d293bac0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.5061925195824346, 0.2534546583645259, 15.0, 2),
#    'ssr_chi2test': (4.016513385553158, 0.13422246181541353, 2),
#    'lrtest': (3.6601875584428, 0.16039852502104474, 2),
#    'params_ftest': (1.5061925195810555, 0.25345465836481684, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d28ddfa0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2914f10>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5686  , p=0.4606  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=0.6633  , p=0.4154  , df=1
# likelihood ratio test: chi2=0.6531  , p=0.4190  , df=1
# parameter F test:         F=0.5686  , p=0.4606  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7673  , p=0.4817  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=2.0461  , p=0.3595  , df=2
# likelihood ratio test: chi2=1.9481  , p=0.3776  , df=2
# parameter F test:         F=0.7673  , p=0.4817  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (0.5685693968546055, 0.4605790756976246, 18.0, 1),
#    'ssr_chi2test': (0.6633309629970399, 0.4153864452952253, 1),
#    'lrtest': (0.6530700980527229, 0.4190171733073951, 1),
#    'params_ftest': (0.5685693968547763, 0.46057907569755774, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d29514c0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d1b52eb0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.7672844711279297, 0.48165698539078594, 15.0, 2),
#    'ssr_chi2test': (2.0460919230078125, 0.35949825294825305, 2),
#    'lrtest': (1.9480615115744229, 0.3775581222999371, 2),
#    'params_ftest': (0.7672844711282072, 0.4816569853906648, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d28b6880>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2951880>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ '工业产值占比%','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=19.0197 , p=0.0004  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=22.1897 , p=0.0000  , df=1
# likelihood ratio test: chi2=15.1427 , p=0.0001  , df=1
# parameter F test:         F=19.0197 , p=0.0004  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3386  , p=0.2918  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.5697  , p=0.1678  , df=2
# likelihood ratio test: chi2=3.2846  , p=0.1935  , df=2
# parameter F test:         F=1.3386  , p=0.2918  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (19.01971313302291, 0.00037646858277662115, 18.0, 1),
#    'ssr_chi2test': (22.189665321860065, 2.4699977025318016e-06, 1),
#    'lrtest': (15.142654805171318, 9.968537128299985e-05, 1),
#    'params_ftest': (19.019713133023075, 0.0003764685827766053, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d28e7910>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d294a8e0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.3386329611185028, 0.291790554537895, 15.0, 2),
#    'ssr_chi2test': (3.5696878963160077, 0.1678232480838547, 2),
#    'lrtest': (3.2845840348301465, 0.19353594578865901, 2),
#    'params_ftest': (1.338632961118467, 0.29179055453790387, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d29723d0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d29724f0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'per human capital (yuan/person)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1661  , p=0.6884  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=0.1938  , p=0.6598  , df=1
# likelihood ratio test: chi2=0.1929  , p=0.6605  , df=1
# parameter F test:         F=0.1661  , p=0.6884  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6671  , p=0.5278  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=1.7790  , p=0.4109  , df=2
# likelihood ratio test: chi2=1.7043  , p=0.4265  , df=2
# parameter F test:         F=0.6671  , p=0.5278  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (0.16611397902005928, 0.6883952855849441, 18.0, 1),
#    'ssr_chi2test': (0.19379964219006915, 0.6597728455822294, 1),
#    'lrtest': (0.19291086084737685, 0.6605048956362978, 1),
#    'params_ftest': (0.16611397901978484, 0.6883952855851889, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d0df09a0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d1d2f850>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.6671133284611034, 0.5277704989002129, 15.0, 2),
#    'ssr_chi2test': (1.7789688758962758, 0.41086752586124187, 2),
#    'lrtest': (1.7042500025126799, 0.4265076390220781, 2),
#    'params_ftest': (0.6671133284609219, 0.5277704989003015, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d28df100>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d1ae4580>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'FDI（亿美元）','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.4876  , p=0.1322  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=2.9022  , p=0.0885  , df=1
# likelihood ratio test: chi2=2.7184  , p=0.0992  , df=1
# parameter F test:         F=2.4876  , p=0.1322  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2275  , p=0.3208  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.2734  , p=0.1946  , df=2
# likelihood ratio test: chi2=3.0315  , p=0.2196  , df=2
# parameter F test:         F=1.2275  , p=0.3208  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.487636903448018, 0.1321561446113424, 18.0, 1),
#    'ssr_chi2test': (2.9022430540226876, 0.0884563850164297, 1),
#    'lrtest': (2.7184472373030104, 0.09919446954776517, 1),
#    'params_ftest': (2.48763690344797, 0.13215614461134578, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d294a5b0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d28ad070>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.227506257089346, 0.32083608562453597, 15.0, 2),
#    'ssr_chi2test': (3.2733500189049227, 0.19462609756655402, 2),
#    'lrtest': (3.031533127880323, 0.21963975238487918, 2),
#    'params_ftest': (1.2275062570893205, 0.3208360856245428, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d0c869d0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d0d47940>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'coal consumpution growth ratio','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.1210  , p=0.1625  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=2.4745  , p=0.1157  , df=1
# likelihood ratio test: chi2=2.3392  , p=0.1262  , df=1
# parameter F test:         F=2.1210  , p=0.1625  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4934  , p=0.0568  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=9.3158  , p=0.0095  , df=2
# likelihood ratio test: chi2=7.6479  , p=0.0218  , df=2
# parameter F test:         F=3.4934  , p=0.0568  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.1209786931138304, 0.16251609927243235, 18.0, 1),
#    'ssr_chi2test': (2.4744751419661353, 0.11570806247284016, 1),
#    'lrtest': (2.3392158079762595, 0.12615304632456675, 1),
#    'params_ftest': (2.120978693113829, 0.16251609927243235, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d21a0e80>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2972b20>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (3.493416841019706, 0.05681516322026037, 15.0, 2),
#    'ssr_chi2test': (9.315778242719219, 0.009486466060214183, 2),
#    'lrtest': (7.647872082076873, 0.02184166180476332, 2),
#    'params_ftest': (3.4934168410197897, 0.056815163220257106, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d29725e0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1d3d2972dc0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
#主要看p值（第二列），所有的p小于0.05才能证明b对a有效

# number of lags (no zero) 1：当lags为1时的检测结果
# ssr based F test：残差平方和F检验
# ssr based chi2 test：残差平方和卡方检验
# likelihood ratio test：似然比检验结果
# parr F testamete：参数 F 检验结果

# %%
from statsmodels.tsa.stattools import adfuller
adf_seq = np.array(data['CO2 emissions'])
dftest = adfuller(adf_seq,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
# Out:
# Test Statistic                 -0.63454
# p-value                         0.86299
# #Lags Used                      0.00000
# Number of Observations Used    21.00000
# Critical Value (1%)            -3.78839
# dtype: float64
# Test Statistic                 -0.63454
# p-value                         0.86299
# #Lags Used                      0.00000
# Number of Observations Used    21.00000
# Critical Value (1%)            -3.78839
# Critical Value (5%)            -3.01310
# dtype: float64
# Test Statistic                 -0.63454
# p-value                         0.86299
# #Lags Used                      0.00000
# Number of Observations Used    21.00000
# Critical Value (1%)            -3.78839
# Critical Value (5%)            -3.01310
# Critical Value (10%)           -2.64640
# dtype: float64

# %% [markdown]
# # Test Statistic : T值，表示T统计量
#
# p-value： p值，表示T统计量对应的概率值
#
# Lags Used：表示延迟
#
# Number of Observations Used: 表示测试的次数
#
# Critical Value 1% : 表示t值下小于 – 4.938690 ， 则原假设发生的概率小于1%， 其它的数值以此类推。
#
# 其中t值和p值是最重要的，其实这两个值是等效的，既可以看t值也可以看p值。
#
# p值越小越好，要求小于给定的显著水平，p值小于0.05，等于0最好。
#
# t值，ADF值要小于t值，1%， 5%， 10% 的三个level，都是一个临界值，如果小于这个临界值，说明拒绝原假设。
#
# 其中，1% ： 严格拒绝原假设； 5%： 拒绝原假设； 10% 以此类推，程度越来越低。如果，ADF小于1% level， 说明严格拒绝原假设
