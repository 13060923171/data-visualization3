# %%
import pandas as pd
import numpy as np

# %%
north = pd.read_excel('data.xlsx',sheet_name='eastern north')
north = north.dropna(how='any',axis=0)

# %%
north
# Out:
#     Unnamed: 0  CO2 emissions  population(万人)  GDP(亿元)   工业产值占比%  \
# 1         1998         602.93         12919.0   9191.5  0.466725
# 2         1999         612.40         12983.0   9760.9  0.473962
# 3         2000         669.33         13045.0  10815.1  0.483380
# 4         2001         655.60         13077.0  11691.2  0.470491
# 5         2002         695.71         13099.0  12684.9  0.463252
# 6         2003         734.40         13115.0  14045.4  0.458798
# 7         2004         882.77         13136.0  16002.1  0.448235
# 8         2005        1019.35         13160.0  18317.4  0.462975
# 9         2006        1090.82         13232.0  21108.4  0.467980
# 10        2007        1123.99         13281.0  25665.7  0.469249
# 11        2008        1304.01         13318.0  30349.0  0.479462
# 12        2009        1410.34         13365.0  32573.6  0.465976
# 13        2010        1634.40         13427.0  36815.0  0.468130
# 14        2011        1910.89         13356.0  43482.6  0.468472
# 15        2012        1990.60         13261.0  48012.5  0.455204
# 16        2013        1914.38         13154.0  51878.2  0.440437
# 17        2014        1912.13         13057.0  54321.2  0.420287
# 18        2015        1822.83         12920.0  54867.3  0.389646
# 19        2016        1843.12         12793.0  56503.8  0.372304
# 20        2017        1850.56         12670.0  59826.1  0.363022
# 21        2018        1950.89         12524.0  63751.6  0.360334
# 22        2019        2139.72         12395.0  67339.0  0.356612
#
#     per human capital (yuan/person)    FDI（亿美元）  \
# 1                             27370   25.810000
# 2                             28965   20.330000
# 3                             31840   20.290000
# 4                             34291   20.360000
# 5                             37234   22.470000
# 6                             41445   24.400000
# 7                             47579   26.680000
# 8                             54598   32.660000
# 9                             62846   43.240000
# 10                            76345   56.960000
# 11                            90155   95.140000
# 12                            97322  113.210000
# 13                           110214  141.200000
# 14                           129992  217.700000
# 15                           144576  207.570100
# 16                           157483  227.930530
# 17                           166503  236.879362
# 18                           170341  243.908111
# 19                           177913  192.870800
# 20                           190194  194.356700
# 21                           204272  217.069000
# 22                           217899  217.676314
#
#     coal consumpution growth ratio
# 1                        -0.089505
# 2                        -0.007964
# 3                         0.066941
# 4                        -0.005801
# 5                         0.041624
# 6                         0.179558
# 7                         0.167715
# 8                         0.163600
# 9                         0.109090
# 10                        0.095392
# 11                        0.110869
# 12                        0.044770
# 13                        0.100394
# 14                        0.171329
# 15                        0.037857
# 16                       -0.039530
# 17                        0.022339
# 18                       -0.017450
# 19                       -0.000052
# 20                        0.038095
# 21                        0.049504
# 22                        0.079235

# %%
data = north.drop(['Unnamed: 0'],axis=1)
data
# Out:
#     CO2 emissions  population(万人)  GDP(亿元)   工业产值占比%  \
# 1          602.93         12919.0   9191.5  0.466725
# 2          612.40         12983.0   9760.9  0.473962
# 3          669.33         13045.0  10815.1  0.483380
# 4          655.60         13077.0  11691.2  0.470491
# 5          695.71         13099.0  12684.9  0.463252
# 6          734.40         13115.0  14045.4  0.458798
# 7          882.77         13136.0  16002.1  0.448235
# 8         1019.35         13160.0  18317.4  0.462975
# 9         1090.82         13232.0  21108.4  0.467980
# 10        1123.99         13281.0  25665.7  0.469249
# 11        1304.01         13318.0  30349.0  0.479462
# 12        1410.34         13365.0  32573.6  0.465976
# 13        1634.40         13427.0  36815.0  0.468130
# 14        1910.89         13356.0  43482.6  0.468472
# 15        1990.60         13261.0  48012.5  0.455204
# 16        1914.38         13154.0  51878.2  0.440437
# 17        1912.13         13057.0  54321.2  0.420287
# 18        1822.83         12920.0  54867.3  0.389646
# 19        1843.12         12793.0  56503.8  0.372304
# 20        1850.56         12670.0  59826.1  0.363022
# 21        1950.89         12524.0  63751.6  0.360334
# 22        2139.72         12395.0  67339.0  0.356612
#
#     per human capital (yuan/person)    FDI（亿美元）  \
# 1                             27370   25.810000
# 2                             28965   20.330000
# 3                             31840   20.290000
# 4                             34291   20.360000
# 5                             37234   22.470000
# 6                             41445   24.400000
# 7                             47579   26.680000
# 8                             54598   32.660000
# 9                             62846   43.240000
# 10                            76345   56.960000
# 11                            90155   95.140000
# 12                            97322  113.210000
# 13                           110214  141.200000
# 14                           129992  217.700000
# 15                           144576  207.570100
# 16                           157483  227.930530
# 17                           166503  236.879362
# 18                           170341  243.908111
# 19                           177913  192.870800
# 20                           190194  194.356700
# 21                           204272  217.069000
# 22                           217899  217.676314
#
#     coal consumpution growth ratio
# 1                        -0.089505
# 2                        -0.007964
# 3                         0.066941
# 4                        -0.005801
# 5                         0.041624
# 6                         0.179558
# 7                         0.167715
# 8                         0.163600
# 9                         0.109090
# 10                        0.095392
# 11                        0.110869
# 12                        0.044770
# 13                        0.100394
# 14                        0.171329
# 15                        0.037857
# 16                       -0.039530
# 17                        0.022339
# 18                       -0.017450
# 19                       -0.000052
# 20                        0.038095
# 21                        0.049504
# 22                        0.079235

# %%
data['CO2 emissions'] = data['CO2 emissions'].apply(np.log)
data['population(万人)'] = data['population(万人)'].apply(np.log)
data['GDP(亿元)'] = data['GDP(亿元)'].apply(np.log)
data['工业产值占比%'] = data['工业产值占比%'].apply(np.log)
data['per human capital (yuan/person)'] = data['per human capital (yuan/person)'].apply(np.log)
data['FDI（亿美元）'] = data['FDI（亿美元）'].apply(np.log)
# data['coal consumpution growth ratio'] = data['coal consumpution growth ratio'].apply(np.log)

# %%
 data.describe()
# Out:
#        CO2 emissions  population(万人)    GDP(亿元)    工业产值占比%  \
# count      22.000000       22.000000  22.000000  22.000000
# mean        7.116720        9.476988  10.229562  -0.823281
# std         0.459966        0.020868   0.692730   0.103028
# min         6.401801        9.425048   9.126034  -1.031107
# 25%         6.645057        9.467748   9.582656  -0.855110
# 50%         7.212393        9.480902  10.355888  -0.769784
# 75%         7.547304        9.492035  10.891166  -0.758461
# max         7.668430        9.505023  11.117495  -0.726953
#
#        per human capital (yuan/person)   FDI（亿美元）  \
# count                        22.000000  22.000000
# mean                         11.335905   4.355190
# std                           0.716341   1.020805
# min                          10.217203   3.010128
# 25%                          10.666629   3.259050
# 50%                          11.447533   4.642297
# 75%                          12.008845   5.369029
# max                          12.291787   5.496792
#
#        coal consumpution growth ratio
# count                       22.000000
# mean                         0.059910
# std                          0.072769
# min                         -0.089505
# 25%                          0.005546
# 50%                          0.047137
# 75%                          0.106916
# max                          0.179558

# %%
 data.corr()
# Out:
#                                  CO2 emissions  population(万人)   GDP(亿元)  \
# CO2 emissions                         1.000000       -0.195050  0.989055
# population(万人)                       -0.195050        1.000000 -0.292456
# GDP(亿元)                               0.989055       -0.292456  1.000000
# 工业产值占比%                              -0.623743        0.846118 -0.708741
# per human capital (yuan/person)       0.986412       -0.315990  0.999678
# FDI（亿美元）                              0.980189       -0.213666  0.976684
# coal consumpution growth ratio        0.011279        0.326699 -0.037018
#
#                                   工业产值占比%  per human capital (yuan/person)  \
# CO2 emissions                   -0.623743                         0.986412
# population(万人)                   0.846118                        -0.315990
# GDP(亿元)                         -0.708741                         0.999678
# 工业产值占比%                          1.000000                        -0.725511
# per human capital (yuan/person) -0.725511                         1.000000
# FDI（亿美元）                        -0.623878                         0.974467
# coal consumpution growth ratio   0.219559                        -0.044663
#
#                                  FDI（亿美元）  coal consumpution growth ratio
# CO2 emissions                    0.980189                        0.011279
# population(万人)                  -0.213666                        0.326699
# GDP(亿元)                          0.976684                       -0.037018
# 工业产值占比%                         -0.623878                        0.219559
# per human capital (yuan/person)  0.974467                       -0.044663
# FDI（亿美元）                         1.000000                       -0.132937
# coal consumpution growth ratio  -0.132937                        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.subplots(figsize = (15,8))
sns.heatmap( data.corr(), annot=True,cmap="PiYG")
plt.title("Correlations Among Features", fontsize = 20)
# 保存图片
plt.savefig('./region/热力图.png')
plt.show()

# %%
#最小二乘法的求解过程

# %%
# standard import
import logging
import os

import numpy


# 样本x
SAMPLE_X = np.array(data['GDP(亿元)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('GDP与CO2线性关系')
# 保存图片
plt.savefig('./north/GDP与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['population(万人)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('population与CO2线性关系')
# 保存图片
plt.savefig('./north/population与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['工业产值占比%'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('工业产值与CO2线性关系')
# 保存图片
plt.savefig('./north/工业产值与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['per human capital (yuan/person)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('capital与CO2线性关系')
# 保存图片
plt.savefig('./north/capital与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['FDI（亿美元）'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('FDI与CO2线性关系')
# 保存图片
plt.savefig('./north/FDI与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['coal consumpution growth ratio'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('ratio与CO2线性关系')
# 保存图片
plt.savefig('./north/ratio与CO2线性关系.png')
# 显示图片
plt.show()

# %%
import numpy as np
from atrader import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import r2_score
set_setting('ALLOW_CONSOLE_SYSTEM_WARN', False)
import statsmodels.api as sm

# %%
train_x = data[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']]
train_y = data['CO2 emissions']

#分割数据，将25%的数据作为测试集，其余作为训练集
train_x,test_x,train_y,test_y = train_test_split(train_x,train_y,test_size=0.3)

# %%
#线性回归多因子 CO2预测

# %%
def co2_predict():
    # 获取各因子数据
    x1 = data['population(万人)']
    x2 = data['GDP(亿元)']
    x3 = data['工业产值占比%']
    x4 = data['per human capital (yuan/person)']
    x5 = data['FDI（亿美元）']
    x6 = data['coal consumpution growth ratio']
    y1 = data['CO2 emissions']

    # 以图的方式展示单个因子与co2的关系
    fig = plt.figure(figsize=(20,5))
    ax1 = plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=1)
    ax1.scatter(x1,y1,label='population')

    ax2 = plt.subplot2grid((6,2),(0,1),rowspan=2,colspan=1)
    ax2.scatter(x2,y1,label='GDP')

    ax3 = plt.subplot2grid((6,2),(2,0),rowspan=2,colspan=1)
    ax3.scatter(x3,y1,label='工业产值')
    
    ax4 = plt.subplot2grid((6,2),(2,1),rowspan=2,colspan=1)
    ax4.scatter(x4,y1,label='capital')
    
    ax5 = plt.subplot2grid((6,2),(4,0),rowspan=2,colspan=1)
    ax5.scatter(x5,y1,label='FDI')
    
    ax6 = plt.subplot2grid((6,2),(4,1),rowspan=2,colspan=1)
    ax6.scatter(x6,y1,label='ratio')
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    ax5.legend()
    ax6.legend()
    plt.savefig("./north/各因子与co2的回归关系")
    plt.show()
    
    # 创建模型
    model = LinearRegression()
    # 模型训练

    model.fit(train_x,train_y)
    # 模型预测
    predict_y = model.predict(test_x)
    #算出它的正确率
    score = r2_score(test_y, predict_y)
    print('多因子线性回归预测正确率:',score)

# %%
co2_predict()
# Out:
# 多因子线性回归预测正确率: 0.9879294312746068

# %%
data1 = north
data1['index'] = range(1, len(data1) + 1)  
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22 non-null     int64
#  1   CO2 emissions                    22 non-null     float64
#  2   population(万人)                   22 non-null     float64
#  3   GDP(亿元)                          22 non-null     float64
#  4   工业产值占比%                          22 non-null     float64
#  5   per human capital (yuan/person)  22 non-null     int64
#  6   FDI（亿美元）                         22 non-null     float64
#  7   coal consumpution growth ratio   22 non-null     float64
#  8   index                            22 non-null     int64
# dtypes: float64(6), int64(3)
# memory usage: 1.7 KB

# %%
data1 = data1.set_index(['index','Unnamed: 0'])
train = data1[['GDP(亿元)','per human capital (yuan/person)','FDI（亿美元）']]
target =  data1['CO2 emissions'].apply(np.log)

# %%
data1['GDP(亿元)'] = data1['GDP(亿元)'].apply(np.log)
data1['per human capital (yuan/person)'] = data1['per human capital (yuan/person)'].apply(np.log)
data1['FDI（亿美元）'] = data1['FDI（亿美元）'].apply(np.log)

# %%
#混合最小二乘
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
#计算回归面板数据
exog = sm.add_constant(data1[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']])
mod = PooledOLS(target, exog)
#模型训练
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:          CO2 emissions   R-squared:                        0.9933
# Estimator:                  PooledOLS   R-squared (Between):              0.9933
# No. Observations:                  22   R-squared (Within):               0.0000
# Date:                Tue, Jul 26 2022   R-squared (Overall):              0.9933
# Time:                        09:48:08   Log-likelihood                    41.398
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      369.13
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(6,15)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             369.13
#                                         P-value                           0.0000
# Time periods:                      22   Distribution:                    F(6,15)
# Avg Obs:                       1.0000
# Min Obs:                       1.0000
# Max Obs:                       1.0000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# const                              -4.8523     4.5401    -1.0688     0.3021     -14.529      4.8248
# population(万人)                      0.0001     0.0002     0.7324     0.4752     -0.0002      0.0005
# GDP(亿元)                            -3.0546     2.5804    -1.1838     0.2549     -8.5546      2.4454
# 工业产值占比%                             2.0456     1.1313     1.8081     0.0907     -0.3658      4.4570
# per human capital (yuan/person)     3.5377     2.5438     1.3907     0.1846     -1.8844      8.9597
# FDI（亿美元）                            0.1115     0.0689     1.6184     0.1264     -0.0353      0.2583
# coal consumpution growth ratio      0.3282     0.1926     1.7044     0.1089     -0.0822      0.7386
# ===================================================================================================
# E:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
data2 = north
data2 = data2.set_index(['Unnamed: 0'])
data2
# Out:
#             CO2 emissions  population(万人)  GDP(亿元)  工业产值占比%  per human capital (yuan/person)   FDI（亿美元）  coal consumpution growth ratio  index
# Unnamed: 0
# 1998               602.93         12919.0   9191.5  0.46672                            27370   25.81000                        -0.08950      1
# 1999               612.40         12983.0   9760.9  0.47396                            28965   20.33000                        -0.00796      2
# 2000               669.33         13045.0  10815.1  0.48338                            31840   20.29000                         0.06694      3
# 2001               655.60         13077.0  11691.2  0.47049                            34291   20.36000                        -0.00580      4
# 2002               695.71         13099.0  12684.9  0.46325                            37234   22.47000                         0.04162      5
# 2003               734.40         13115.0  14045.4  0.45880                            41445   24.40000                         0.17956      6
# 2004               882.77         13136.0  16002.1  0.44823                            47579   26.68000                         0.16771      7
# 2005              1019.35         13160.0  18317.4  0.46298                            54598   32.66000                         0.16360      8
# 2006              1090.82         13232.0  21108.4  0.46798                            62846   43.24000                         0.10909      9
# 2007              1123.99         13281.0  25665.7  0.46925                            76345   56.96000                         0.09539     10
# 2008              1304.01         13318.0  30349.0  0.47946                            90155   95.14000                         0.11087     11
# 2009              1410.34         13365.0  32573.6  0.46598                            97322  113.21000                         0.04477     12
# 2010              1634.40         13427.0  36815.0  0.46813                           110214  141.20000                         0.10039     13
# 2011              1910.89         13356.0  43482.6  0.46847                           129992  217.70000                         0.17133     14
# 2012              1990.60         13261.0  48012.5  0.45520                           144576  207.57010                         0.03786     15
# 2013              1914.38         13154.0  51878.2  0.44044                           157483  227.93053                        -0.03953     16
# 2014              1912.13         13057.0  54321.2  0.42029                           166503  236.87936                         0.02234     17
# 2015              1822.83         12920.0  54867.3  0.38965                           170341  243.90811                        -0.01745     18
# 2016              1843.12         12793.0  56503.8  0.37230                           177913  192.87080                         0.00000     19
# 2017              1850.56         12670.0  59826.1  0.36302                           190194  194.35670                         0.03809     20
# 2018              1950.89         12524.0  63751.6  0.36033                           204272  217.06900                         0.04950     21
# 2019              2139.72         12395.0  67339.0  0.35661                           217899  217.67631                         0.07924     22

# %%
#导入对应的acf和pacf
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
#导入时间模型
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
#导入画图库
import matplotlib.pyplot as plt

# %%
#测试数据
d1 = data2['CO2 emissions'].apply(np.log)
#原始数据之后的时间趋势
plt.figure(figsize=(12,8),dpi=300)
plt.plot(d1)
plt.title('CO2时间变化趋势')
plt.savefig('./north/CO2时间变化趋势.png')
plt.show()

# %%
#由于上图不是很平稳，所以对该时间进行时间序列的差分，找出合适的差分次数
plt.figure(figsize=(12,8),dpi=300)
#这个是一阶差分，可以看出时间序列的均值和方差基本平稳
diff1 = d1.diff(1)
plt.plot(diff1)
plt.title('一阶差分时间变化趋势')
plt.savefig('./north/一阶差分时间变化趋势.png')
plt.show()

# %%
#格兰杰因果检验
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CO2 emissions                    22 non-null     float64
#  1   population(万人)                   22 non-null     float64
#  2   GDP(亿元)                          22 non-null     float64
#  3   工业产值占比%                          22 non-null     float64
#  4   per human capital (yuan/person)  22 non-null     float64
#  5   FDI（亿美元）                         22 non-null     float64
#  6   coal consumpution growth ratio   22 non-null     float64
# dtypes: float64(7)
# memory usage: 1.4 KB

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0592  , p=0.0973  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=3.5691  , p=0.0589  , df=1
# likelihood ratio test: chi2=3.2963  , p=0.0694  , df=1
# parameter F test:         F=3.0592  , p=0.0973  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1880  , p=0.8306  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=0.5012  , p=0.7783  , df=2
# likelihood ratio test: chi2=0.4950  , p=0.7807  , df=2
# parameter F test:         F=0.1880  , p=0.8306  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (3.0592103172782177, 0.09731205260817109, 18.0, 1),
#    'ssr_chi2test': (3.5690787034912534, 0.05886496159162789, 1),
#    'lrtest': (3.2962912773260484, 0.06943649210783644, 1),
#    'params_ftest': (3.0592103172786196, 0.09731205260815073, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175897ba2e0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17582ecd6d0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.1879554508859322, 0.8305734413185887, 15.0, 2),
#    'ssr_chi2test': (0.5012145356958193, 0.7783279859676882, 2),
#    'lrtest': (0.4950371295823288, 0.7807357264806674, 2),
#    'params_ftest': (0.18795545088589038, 0.8305734413186227, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175897657f0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758034c1c0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'population(万人)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=58.5509 , p=0.0000  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=68.3093 , p=0.0000  , df=1
# likelihood ratio test: chi2=30.3993 , p=0.0000  , df=1
# parameter F test:         F=58.5509 , p=0.0000  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3274  , p=0.2946  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.5397  , p=0.1704  , df=2
# likelihood ratio test: chi2=3.2591  , p=0.1960  , df=2
# parameter F test:         F=1.3274  , p=0.2946  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (58.55085371203261, 4.5911920198316275e-07, 18.0, 1),
#    'ssr_chi2test': (68.30932933070471, 1.3975820894196046e-16, 1),
#    'lrtest': (30.399253846303452, 3.5166339896649984e-08, 1),
#    'params_ftest': (58.55085371197838, 4.591192019861346e-07, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175897e8d60>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758981fe20>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.3273958301966395, 0.29458794164883095, 15.0, 2),
#    'ssr_chi2test': (3.539722213857706, 0.17035664854039229, 2),
#    'lrtest': (3.2591405521546903, 0.19601378784509602, 2),
#    'params_ftest': (1.3273958301963062, 0.2945879416489147, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589800fa0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589800ac0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.0592  , p=0.0973  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=3.5691  , p=0.0589  , df=1
# likelihood ratio test: chi2=3.2963  , p=0.0694  , df=1
# parameter F test:         F=3.0592  , p=0.0973  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1880  , p=0.8306  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=0.5012  , p=0.7783  , df=2
# likelihood ratio test: chi2=0.4950  , p=0.7807  , df=2
# parameter F test:         F=0.1880  , p=0.8306  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (3.0592103172782177, 0.09731205260817109, 18.0, 1),
#    'ssr_chi2test': (3.5690787034912534, 0.05886496159162789, 1),
#    'lrtest': (3.2962912773260484, 0.06943649210783644, 1),
#    'params_ftest': (3.0592103172786196, 0.09731205260815073, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758980ec10>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589750bb0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.1879554508859322, 0.8305734413185887, 15.0, 2),
#    'ssr_chi2test': (0.5012145356958193, 0.7783279859676882, 2),
#    'lrtest': (0.4950371295823288, 0.7807357264806674, 2),
#    'params_ftest': (0.18795545088589038, 0.8305734413186227, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175898161c0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175899122e0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ '工业产值占比%','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.4627  , p=0.0489  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=5.2064  , p=0.0225  , df=1
# likelihood ratio test: chi2=4.6511  , p=0.0310  , df=1
# parameter F test:         F=4.4627  , p=0.0489  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3533  , p=0.1292  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=6.2754  , p=0.0434  , df=2
# likelihood ratio test: chi2=5.4580  , p=0.0653  , df=2
# parameter F test:         F=2.3533  , p=0.1292  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (4.4626707165164, 0.04887701541957622, 18.0, 1),
#    'ssr_chi2test': (5.206449169269133, 0.022503248558892457, 1),
#    'lrtest': (4.651144979294969, 0.031032841490305833, 1),
#    'params_ftest': (4.4626707165164765, 0.048877015419574454, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589807880>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589807700>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.3532893220752364, 0.12915172516706427, 15.0, 2),
#    'ssr_chi2test': (6.275438192200631, 0.043381634480007925, 2),
#    'lrtest': (5.45804640446346, 0.06528302684882364, 2),
#    'params_ftest': (2.3532893220751774, 0.12915172516707005, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758980ea90>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758980ebe0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'per human capital (yuan/person)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9875  , p=0.1010  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=3.4854  , p=0.0619  , df=1
# likelihood ratio test: chi2=3.2247  , p=0.0725  , df=1
# parameter F test:         F=2.9875  , p=0.1010  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0910  , p=0.9135  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=0.2427  , p=0.8857  , df=2
# likelihood ratio test: chi2=0.2412  , p=0.8864  , df=2
# parameter F test:         F=0.0910  , p=0.9135  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.987495734240174, 0.10102489783978454, 18.0, 1),
#    'ssr_chi2test': (3.4854116899468695, 0.06191195984803356, 1),
#    'lrtest': (3.2246562863564634, 0.07253702284076512, 1),
#    'params_ftest': (2.987495734240256, 0.10102489783978019, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175898009a0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589826730>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.09101104932638122, 0.9135078813565508, 15.0, 2),
#    'ssr_chi2test': (0.2426961315370166, 0.8857256151669882, 2),
#    'lrtest': (0.24123540147513722, 0.8863727544785083, 2),
#    'params_ftest': (0.09101104932642941, 0.9135078813565076, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17582ecd730>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589775400>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'FDI（亿美元）','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.9006 , p=0.0009  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=18.5508 , p=0.0000  , df=1
# likelihood ratio test: chi2=13.2943 , p=0.0003  , df=1
# parameter F test:         F=15.9006 , p=0.0009  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6654  , p=0.1022  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=7.1076  , p=0.0286  , df=2
# likelihood ratio test: chi2=6.0816  , p=0.0478  , df=2
# parameter F test:         F=2.6654  , p=0.1022  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (15.900643982868894, 0.0008634222337057062, 18.0, 1),
#    'ssr_chi2test': (18.550751313347046, 1.654400069936232e-05, 1),
#    'lrtest': (13.29430730994686, 0.00026621318165545257, 1),
#    'params_ftest': (15.900643982868687, 0.0008634222337057558, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758981f880>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758980ef70>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.665353292839899, 0.10222118192950594, 15.0, 2),
#    'ssr_chi2test': (7.107608780906397, 0.02861556751741885, 2),
#    'lrtest': (6.081643634943006, 0.047795594095298925, 2),
#    'params_ftest': (2.665353292839932, 0.10222118192950352, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589826520>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589826790>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'coal consumpution growth ratio','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6203  , p=0.1229  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=3.0570  , p=0.0804  , df=1
# likelihood ratio test: chi2=2.8540  , p=0.0911  , df=1
# parameter F test:         F=2.6203  , p=0.1229  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1960  , p=0.3297  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.1893  , p=0.2030  , df=2
# likelihood ratio test: chi2=2.9591  , p=0.2277  , df=2
# parameter F test:         F=1.1960  , p=0.3297  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.62027187427464, 0.12289457125962615, 18.0, 1),
#    'ssr_chi2test': (3.0569838533204137, 0.08039076524273224, 1),
#    'lrtest': (2.853961017287091, 0.09114911206091063, 1),
#    'params_ftest': (2.6202718742746427, 0.12289457125962594, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589775430>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x175898266a0>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.1959697628484243, 0.32966612106817217, 15.0, 2),
#    'ssr_chi2test': (3.189252700929132, 0.20298435934615205, 2),
#    'lrtest': (2.9591330427450515, 0.22773638584660966, 2),
#    'params_ftest': (1.1959697628485153, 0.32966612106814636, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x17589826fd0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1758984a310>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
#主要看p值（第二列），所有的p小于0.05才能证明b对a有效

# number of lags (no zero) 1：当lags为1时的检测结果
# ssr based F test：残差平方和F检验
# ssr based chi2 test：残差平方和卡方检验
# likelihood ratio test：似然比检验结果
# parr F testamete：参数 F 检验结果

# %%
from statsmodels.tsa.stattools import adfuller
adf_seq = np.array(data['CO2 emissions'])
dftest = adfuller(adf_seq,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
# Out:
# Test Statistic                 -0.26850
# p-value                         0.92985
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# dtype: float64
# Test Statistic                 -0.26850
# p-value                         0.92985
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# Critical Value (5%)            -3.15497
# dtype: float64
# Test Statistic                 -0.26850
# p-value                         0.92985
# #Lags Used                      9.00000
# Number of Observations Used    12.00000
# Critical Value (1%)            -4.13783
# Critical Value (5%)            -3.15497
# Critical Value (10%)           -2.71448
# dtype: float64

# %% [markdown]
# # Test Statistic : T值，表示T统计量
#
# p-value： p值，表示T统计量对应的概率值
#
# Lags Used：表示延迟
#
# Number of Observations Used: 表示测试的次数
#
# Critical Value 1% : 表示t值下小于 – 4.938690 ， 则原假设发生的概率小于1%， 其它的数值以此类推。
#
# 其中t值和p值是最重要的，其实这两个值是等效的，既可以看t值也可以看p值。
#
# p值越小越好，要求小于给定的显著水平，p值小于0.05，等于0最好。
#
# t值，ADF值要小于t值，1%， 5%， 10% 的三个level，都是一个临界值，如果小于这个临界值，说明拒绝原假设。
#
# 其中，1% ： 严格拒绝原假设； 5%： 拒绝原假设； 10% 以此类推，程度越来越低。如果，ADF小于1% level， 说明严格拒绝原假设
