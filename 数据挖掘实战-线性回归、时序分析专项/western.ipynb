# %%
import pandas as pd
import numpy as np

# %%
western = pd.read_excel('data.xlsx',sheet_name='western')
western = western.dropna(how='any',axis=0)

# %%
western
# Out:
#     Unnamed: 0  CO2 emissions  population(万人)   GDP(亿元)   工业产值占比%  \
# 1         1998         658.44         33185.0   13708.5  0.391195
# 2         1999         595.41         33484.0   14467.7  0.387325
# 3         2000         568.86         33263.0   15787.3  0.387951
# 4         2001         574.87         33248.0   17284.0  0.385756
# 5         2002         618.59         33383.0   19108.5  0.386263
# 6         2003         789.67         33611.0   21712.8  0.397710
# 7         2004         902.50         33679.0   25601.5  0.407398
# 8         2005        1121.33         33514.0   19348.7  0.632993
# 9         2006        1193.95         33602.0   34477.9  0.436303
# 10        2007        1313.85         33659.0   42531.2  0.438845
# 11        2008        1517.63         33796.0   51458.5  0.445118
# 12        2009        1686.70         33927.0   56541.0  0.442000
# 13        2010        1862.08         33597.0   68474.7  0.456449
# 14        2011        2102.49         33880.0   84088.4  0.457043
# 15        2012        2274.06         34107.0   95978.0  0.453102
# 16        2013        2370.82         34304.0  107974.3  0.443360
# 17        2014        2434.92         34544.0  118764.4  0.436142
# 18        2015        2394.68         34793.0  126077.0  0.413602
# 19        2016        2521.18         35092.0  137236.6  0.395860
# 20        2017        2628.95         35382.0  154838.0  0.387686
# 21        2018        2610.45         35573.0  173014.5  0.382421
# 22        2019        2703.68         35763.0  187695.8  0.375401
#
#     per human capital (yuan/person)    FDI（亿美元）  \
# 1                             47582   37.440000
# 2                             50421   36.920000
# 3                             55153   41.050000
# 4                             60647   47.110000
# 5                             66969   56.980000
# 6                             75993   75.570000
# 7                             88568   79.320000
# 8                            100478   69.590000
# 9                            116856  102.370000
# 10                           142815  143.000000
# 11                           172465  183.190000
# 12                           187167  220.770000
# 13                           226252  281.740000
# 14                           275325  330.430000
# 15                           309834  366.098500
# 16                           346337  403.443400
# 17                           377630  387.166800
# 18                           397910  162.235400
# 19                           429683  141.362100
# 20                           478775  165.217600
# 21                           529722  163.567200
# 22                           569543   59.272058
#
#     coal consumpution growth ratio
# 1                         0.001452
# 2                        -0.066811
# 3                         0.003014
# 4                        -0.037199
# 5                         0.084016
# 6                         0.309557
# 7                         0.150789
# 8                         0.095051
# 9                         0.130892
# 10                        0.092104
# 11                        0.071530
# 12                        0.113007
# 13                        0.087237
# 14                        0.126638
# 15                        0.082230
# 16                        0.037650
# 17                        0.007543
# 18                       -0.030212
# 19                        0.033727
# 20                        0.025720
# 21                        0.013841
# 22                        0.059873

# %%
data = western.drop(['Unnamed: 0'],axis=1)
data
# Out:
#     CO2 emissions  population(万人)   GDP(亿元)   工业产值占比%  \
# 1          658.44         33185.0   13708.5  0.391195
# 2          595.41         33484.0   14467.7  0.387325
# 3          568.86         33263.0   15787.3  0.387951
# 4          574.87         33248.0   17284.0  0.385756
# 5          618.59         33383.0   19108.5  0.386263
# 6          789.67         33611.0   21712.8  0.397710
# 7          902.50         33679.0   25601.5  0.407398
# 8         1121.33         33514.0   19348.7  0.632993
# 9         1193.95         33602.0   34477.9  0.436303
# 10        1313.85         33659.0   42531.2  0.438845
# 11        1517.63         33796.0   51458.5  0.445118
# 12        1686.70         33927.0   56541.0  0.442000
# 13        1862.08         33597.0   68474.7  0.456449
# 14        2102.49         33880.0   84088.4  0.457043
# 15        2274.06         34107.0   95978.0  0.453102
# 16        2370.82         34304.0  107974.3  0.443360
# 17        2434.92         34544.0  118764.4  0.436142
# 18        2394.68         34793.0  126077.0  0.413602
# 19        2521.18         35092.0  137236.6  0.395860
# 20        2628.95         35382.0  154838.0  0.387686
# 21        2610.45         35573.0  173014.5  0.382421
# 22        2703.68         35763.0  187695.8  0.375401
#
#     per human capital (yuan/person)    FDI（亿美元）  \
# 1                             47582   37.440000
# 2                             50421   36.920000
# 3                             55153   41.050000
# 4                             60647   47.110000
# 5                             66969   56.980000
# 6                             75993   75.570000
# 7                             88568   79.320000
# 8                            100478   69.590000
# 9                            116856  102.370000
# 10                           142815  143.000000
# 11                           172465  183.190000
# 12                           187167  220.770000
# 13                           226252  281.740000
# 14                           275325  330.430000
# 15                           309834  366.098500
# 16                           346337  403.443400
# 17                           377630  387.166800
# 18                           397910  162.235400
# 19                           429683  141.362100
# 20                           478775  165.217600
# 21                           529722  163.567200
# 22                           569543   59.272058
#
#     coal consumpution growth ratio
# 1                         0.001452
# 2                        -0.066811
# 3                         0.003014
# 4                        -0.037199
# 5                         0.084016
# 6                         0.309557
# 7                         0.150789
# 8                         0.095051
# 9                         0.130892
# 10                        0.092104
# 11                        0.071530
# 12                        0.113007
# 13                        0.087237
# 14                        0.126638
# 15                        0.082230
# 16                        0.037650
# 17                        0.007543
# 18                       -0.030212
# 19                        0.033727
# 20                        0.025720
# 21                        0.013841
# 22                        0.059873

# %%
data['CO2 emissions'] = data['CO2 emissions'].apply(np.log)
data['population(万人)'] = data['population(万人)'].apply(np.log)
data['GDP(亿元)'] = data['GDP(亿元)'].apply(np.log)
data['工业产值占比%'] = data['工业产值占比%'].apply(np.log)
data['per human capital (yuan/person)'] = data['per human capital (yuan/person)'].apply(np.log)
data['FDI（亿美元）'] = data['FDI（亿美元）'].apply(np.log)
# data['coal consumpution growth ratio'] = data['coal consumpution growth ratio'].apply(np.log)

# %%
 data.describe()
# Out:
#        CO2 emissions  population(万人)    GDP(亿元)    工业产值占比%  \
# count      22.000000       22.000000  22.000000  22.000000
# mean        7.239107       10.435715  10.829082  -0.863366
# std         0.582638        0.022895   0.910186   0.113183
# min         6.343634       10.409853   9.525771  -0.979762
# 25%         6.705004       10.420337   9.899200  -0.947388
# 50%         7.377717       10.426364  10.895626  -0.890408
# 75%         7.778501       10.448246  11.661085  -0.814141
# max         7.902369       10.484669  12.142578  -0.457295
#
#        per human capital (yuan/person)   FDI（亿美元）  \
# count                        22.000000  22.000000
# mean                         12.045299   4.800541
# std                           0.846638   0.794778
# min                          10.770210   3.608753
# 25%                          11.276679   4.122259
# 50%                          12.098853   4.957085
# 75%                          12.820045   5.350472
# max                          13.252590   6.000036
#
#        coal consumpution growth ratio
# count                       22.000000
# mean                         0.063257
# std                          0.079988
# min                         -0.066811
# 25%                          0.009117
# 50%                          0.065702
# 75%                          0.094315
# max                          0.309557

# %%
 data.corr()
# Out:
#                                  CO2 emissions  population(万人)   GDP(亿元)  \
# CO2 emissions                         1.000000        0.818985  0.972671
# population(万人)                        0.818985        1.000000  0.891637
# GDP(亿元)                               0.972671        0.891637  1.000000
# 工业产值占比%                               0.156185       -0.250814 -0.054727
# per human capital (yuan/person)       0.983636        0.888248  0.995139
# FDI（亿美元）                              0.791391        0.365277  0.719941
# coal consumpution growth ratio       -0.032048       -0.188347 -0.104505
#
#                                   工业产值占比%  per human capital (yuan/person)  \
# CO2 emissions                    0.156185                         0.983636
# population(万人)                  -0.250814                         0.888248
# GDP(亿元)                         -0.054727                         0.995139
# 工业产值占比%                          1.000000                         0.030437
# per human capital (yuan/person)  0.030437                         1.000000
# FDI（亿美元）                         0.337217                         0.724750
# coal consumpution growth ratio   0.246289                        -0.090467
#
#                                  FDI（亿美元）  coal consumpution growth ratio
# CO2 emissions                    0.791391                       -0.032048
# population(万人)                   0.365277                       -0.188347
# GDP(亿元)                          0.719941                       -0.104505
# 工业产值占比%                          0.337217                        0.246289
# per human capital (yuan/person)  0.724750                       -0.090467
# FDI（亿美元）                         1.000000                        0.135310
# coal consumpution growth ratio   0.135310                        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.subplots(figsize = (15,8))
sns.heatmap( data.corr(), annot=True,cmap="PiYG")
plt.title("Correlations Among Features", fontsize = 20)
# 保存图片
plt.savefig('./western/热力图.png')
plt.show()

# %%
#最小二乘法的求解过程

# %%
# standard import
import logging
import os

import numpy


# 样本x
SAMPLE_X = np.array(data['GDP(亿元)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('GDP与CO2线性关系')
# 保存图片
plt.savefig('./western/GDP与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['population(万人)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('population与CO2线性关系')
# 保存图片
plt.savefig('./western/population与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['工业产值占比%'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('工业产值与CO2线性关系')
# 保存图片
plt.savefig('./western/工业产值与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['per human capital (yuan/person)'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('capital与CO2线性关系')
# 保存图片
plt.savefig('./western/capital与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['FDI（亿美元）'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('FDI与CO2线性关系')
# 保存图片
plt.savefig('./western/FDI与CO2线性关系.png')
# 显示图片
plt.show()

# %%
# standard import
import logging
import os

import matplotlib
import numpy


# 样本x
SAMPLE_X = np.array(data['coal consumpution growth ratio'])

# 样本y
SAMPLE_Y = np.array(data['CO2 emissions'])

# 样本数量
N_SAMPLES = SAMPLE_X.shape[0]

# 样本x的平均值
MEAN_X = sum(SAMPLE_X) / N_SAMPLES

# 样本y的平均值
MEAN_Y = sum(SAMPLE_Y) / N_SAMPLES

# 权重
WEIGHT = ((sum(SAMPLE_X[i] * SAMPLE_Y[i] for i in range(N_SAMPLES)) - N_SAMPLES * MEAN_X * MEAN_Y) /
          sum((SAMPLE_X[i] - MEAN_X) * (SAMPLE_X[i] - MEAN_X) for i in range(N_SAMPLES)))

# 偏置
BIAS = MEAN_Y - WEIGHT * MEAN_X
plt.figure(figsize=(9, 6),dpi=300)  
# 绘制样本
plt.plot(SAMPLE_X, SAMPLE_Y, 'ro', label='样本')
# 绘制拟合直线
plt.plot(SAMPLE_X, SAMPLE_X * WEIGHT + BIAS, label='拟合')
# 显示图例
plt.legend()
# 显示标题
plt.title('ratio与CO2线性关系')
# 保存图片
plt.savefig('./western/ratio与CO2线性关系.png')
# 显示图片
plt.show()

# %%
import numpy as np
from atrader import *
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import r2_score
set_setting('ALLOW_CONSOLE_SYSTEM_WARN', False)
import statsmodels.api as sm

# %%
train_x = data[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']]
train_y = data['CO2 emissions']

#分割数据，将25%的数据作为测试集，其余作为训练集
train_x,test_x,train_y,test_y = train_test_split(train_x,train_y,test_size=0.3)

# %%
#线性回归多因子 CO2预测

# %%
def co2_predict():
    # 获取各因子数据
    x1 = data['population(万人)']
    x2 = data['GDP(亿元)']
    x3 = data['工业产值占比%']
    x4 = data['per human capital (yuan/person)']
    x5 = data['FDI（亿美元）']
    x6 = data['coal consumpution growth ratio']
    y1 = data['CO2 emissions']

    # 以图的方式展示单个因子与co2的关系
    fig = plt.figure(figsize=(20,5))
    ax1 = plt.subplot2grid((6,2),(0,0),rowspan=2,colspan=1)
    ax1.scatter(x1,y1,label='population')

    ax2 = plt.subplot2grid((6,2),(0,1),rowspan=2,colspan=1)
    ax2.scatter(x2,y1,label='GDP')

    ax3 = plt.subplot2grid((6,2),(2,0),rowspan=2,colspan=1)
    ax3.scatter(x3,y1,label='工业产值')
    
    ax4 = plt.subplot2grid((6,2),(2,1),rowspan=2,colspan=1)
    ax4.scatter(x4,y1,label='capital')
    
    ax5 = plt.subplot2grid((6,2),(4,0),rowspan=2,colspan=1)
    ax5.scatter(x5,y1,label='FDI')
    
    ax6 = plt.subplot2grid((6,2),(4,1),rowspan=2,colspan=1)
    ax6.scatter(x6,y1,label='ratio')
    ax1.legend()
    ax2.legend()
    ax3.legend()
    ax4.legend()
    ax5.legend()
    ax6.legend()
    plt.savefig("./western/各因子与co2的回归关系")
    plt.show()
    
    # 创建模型
    model = LinearRegression()
    # 模型训练

    model.fit(train_x,train_y)
    # 模型预测
    predict_y = model.predict(test_x)
    #算出它的正确率
    score = r2_score(test_y, predict_y)
    print('多因子线性回归预测正确率:',score)

# %%
co2_predict()
# Out:
# 多因子线性回归预测正确率: 0.9960365878539134

# %%
data1 = western
data1['index'] = range(1, len(data1) + 1)  
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22 non-null     int64
#  1   CO2 emissions                    22 non-null     float64
#  2   population(万人)                   22 non-null     float64
#  3   GDP(亿元)                          22 non-null     float64
#  4   工业产值占比%                          22 non-null     float64
#  5   per human capital (yuan/person)  22 non-null     int64
#  6   FDI（亿美元）                         22 non-null     float64
#  7   coal consumpution growth ratio   22 non-null     float64
#  8   index                            22 non-null     int64
# dtypes: float64(6), int64(3)
# memory usage: 1.7 KB

# %%
data1 = data1.set_index(['index','Unnamed: 0'])
train = data1[['GDP(亿元)','per human capital (yuan/person)','FDI（亿美元）']]
target =  data1['CO2 emissions'].apply(np.log)

# %%
data1['GDP(亿元)'] = data1['GDP(亿元)'].apply(np.log)
data1['per human capital (yuan/person)'] = data1['per human capital (yuan/person)'].apply(np.log)
data1['FDI（亿美元）'] = data1['FDI（亿美元）'].apply(np.log)

# %%
#混合最小二乘
from linearmodels.panel import PooledOLS
import statsmodels.api as sm
#计算回归面板数据
exog = sm.add_constant(data1[['population(万人)','GDP(亿元)','工业产值占比%','per human capital (yuan/person)','FDI（亿美元）','coal consumpution growth ratio']])
mod = PooledOLS(target, exog)
#模型训练
pooled_res = mod.fit()
print(pooled_res)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:          CO2 emissions   R-squared:                        0.9954
# Estimator:                  PooledOLS   R-squared (Between):              0.9954
# No. Observations:                  22   R-squared (Within):               0.0000
# Date:                Tue, Jul 26 2022   R-squared (Overall):              0.9954
# Time:                        09:50:41   Log-likelihood                    40.392
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      541.70
# Entities:                          22   P-value                           0.0000
# Avg Obs:                       1.0000   Distribution:                    F(6,15)
# Min Obs:                       1.0000
# Max Obs:                       1.0000   F-statistic (robust):             541.70
#                                         P-value                           0.0000
# Time periods:                      22   Distribution:                    F(6,15)
# Avg Obs:                       1.0000
# Min Obs:                       1.0000
# Max Obs:                       1.0000
#
#                                         Parameter Estimates
# ===================================================================================================
#                                  Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------------
# const                              -2.7219     1.6187    -1.6816     0.1133     -6.1720      0.7282
# population(万人)                      0.0002  8.284e-05     2.7244     0.0157   4.912e-05      0.0004
# GDP(亿元)                             3.1389     0.6067     5.1738     0.0001      1.8458      4.4321
# 工业产值占比%                             6.6969     1.1497     5.8251     0.0000      4.2465      9.1474
# per human capital (yuan/person)    -2.8720     0.6855    -4.1896     0.0008     -4.3331     -1.4109
# FDI（亿美元）                            0.0049     0.0438     0.1126     0.9118     -0.0885      0.0984
# coal consumpution growth ratio      0.1337     0.1361     0.9822     0.3416     -0.1564      0.4237
# ===================================================================================================
# E:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
data2 = western
data2 = data2.set_index(['Unnamed: 0'])
data2
# Out:
#             CO2 emissions  population(万人)   GDP(亿元)  工业产值占比%  per human capital (yuan/person)   FDI（亿美元）  coal consumpution growth ratio  index
# Unnamed: 0
# 1998               658.44         33185.0   13708.5  0.39120                            47582   37.44000                         0.00145      1
# 1999               595.41         33484.0   14467.7  0.38732                            50421   36.92000                        -0.06681      2
# 2000               568.86         33263.0   15787.3  0.38795                            55153   41.05000                         0.00301      3
# 2001               574.87         33248.0   17284.0  0.38576                            60647   47.11000                        -0.03720      4
# 2002               618.59         33383.0   19108.5  0.38626                            66969   56.98000                         0.08402      5
# 2003               789.67         33611.0   21712.8  0.39771                            75993   75.57000                         0.30956      6
# 2004               902.50         33679.0   25601.5  0.40740                            88568   79.32000                         0.15079      7
# 2005              1121.33         33514.0   19348.7  0.63299                           100478   69.59000                         0.09505      8
# 2006              1193.95         33602.0   34477.9  0.43630                           116856  102.37000                         0.13089      9
# 2007              1313.85         33659.0   42531.2  0.43884                           142815  143.00000                         0.09210     10
# 2008              1517.63         33796.0   51458.5  0.44512                           172465  183.19000                         0.07153     11
# 2009              1686.70         33927.0   56541.0  0.44200                           187167  220.77000                         0.11301     12
# 2010              1862.08         33597.0   68474.7  0.45645                           226252  281.74000                         0.08724     13
# 2011              2102.49         33880.0   84088.4  0.45704                           275325  330.43000                         0.12664     14
# 2012              2274.06         34107.0   95978.0  0.45310                           309834  366.09850                         0.08223     15
# 2013              2370.82         34304.0  107974.3  0.44336                           346337  403.44340                         0.03765     16
# 2014              2434.92         34544.0  118764.4  0.43614                           377630  387.16680                         0.00754     17
# 2015              2394.68         34793.0  126077.0  0.41360                           397910  162.23540                        -0.03021     18
# 2016              2521.18         35092.0  137236.6  0.39586                           429683  141.36210                         0.03373     19
# 2017              2628.95         35382.0  154838.0  0.38769                           478775  165.21760                         0.02572     20
# 2018              2610.45         35573.0  173014.5  0.38242                           529722  163.56720                         0.01384     21
# 2019              2703.68         35763.0  187695.8  0.37540                           569543   59.27206                         0.05987     22

# %%
#导入对应的acf和pacf
from statsmodels.graphics.tsaplots import acf,pacf,plot_acf,plot_pacf
#导入时间模型
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
#导入画图库
import matplotlib.pyplot as plt

# %%
#测试数据
d1 = data2['CO2 emissions'].apply(np.log)
#原始数据之后的时间趋势
plt.figure(figsize=(12,8),dpi=300)
plt.plot(d1)
plt.title('CO2时间变化趋势')
plt.savefig('./western/CO2时间变化趋势.png')
plt.show()

# %%
#由于上图不是很平稳，所以对该时间进行时间序列的差分，找出合适的差分次数
plt.figure(figsize=(12,8),dpi=300)
#这个是一阶差分，可以看出时间序列的均值和方差基本平稳
diff1 = d1.diff(1)
plt.plot(diff1)
plt.title('一阶差分时间变化趋势')
plt.savefig('./western/一阶差分时间变化趋势.png')
plt.show()

# %%
#格兰杰因果检验
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1 to 22
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   CO2 emissions                    22 non-null     float64
#  1   population(万人)                   22 non-null     float64
#  2   GDP(亿元)                          22 non-null     float64
#  3   工业产值占比%                          22 non-null     float64
#  4   per human capital (yuan/person)  22 non-null     float64
#  5   FDI（亿美元）                         22 non-null     float64
#  6   coal consumpution growth ratio   22 non-null     float64
# dtypes: float64(7)
# memory usage: 1.4 KB

# %%
from statsmodels.tsa.stattools import grangercausalitytests

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.4231  , p=0.0095  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=9.8269  , p=0.0017  , df=1
# likelihood ratio test: chi2=8.0612  , p=0.0045  , df=1
# parameter F test:         F=8.4231  , p=0.0095  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6862  , p=0.0499  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=9.8298  , p=0.0073  , df=2
# likelihood ratio test: chi2=7.9955  , p=0.0184  , df=2
# parameter F test:         F=3.6862  , p=0.0499  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (8.423093601741293, 0.009498981581317293, 18.0, 1),
#    'ssr_chi2test': (9.826942535364841, 0.0017197397848732236, 1),
#    'lrtest': (8.061199177926966, 0.004522324224186129, 1),
#    'params_ftest': (8.42309360174131, 0.009498981581317232, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e662e0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e2139ed820>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (3.6861803259411143, 0.049870744881852766, 15.0, 2),
#    'ssr_chi2test': (9.829814202509638, 0.007336399403056066, 2),
#    'lrtest': (7.995521928170064, 0.018356694207025893, 2),
#    'params_ftest': (3.6861803259411166, 0.049870744881852704, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e83820>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e837f0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'population(万人)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2493  , p=0.2784  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=1.4575  , p=0.2273  , df=1
# likelihood ratio test: chi2=1.4091  , p=0.2352  , df=1
# parameter F test:         F=1.2493  , p=0.2784  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7617  , p=0.4841  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=2.0312  , p=0.3622  , df=2
# likelihood ratio test: chi2=1.9346  , p=0.3801  , df=2
# parameter F test:         F=0.7617  , p=0.4841  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (1.2492856775065795, 0.278385633796303, 18.0, 1),
#    'ssr_chi2test': (1.4574999570910094, 0.227328322964663, 1),
#    'lrtest': (1.4091460842296328, 0.2351981998324933, 1),
#    'params_ftest': (1.2492856775060979, 0.27838563379639264, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e90670>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e2137b5520>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (0.7617131750262656, 0.48409837563815505, 15.0, 2),
#    'ssr_chi2test': (2.0312351334033747, 0.36217869125307445, 2),
#    'lrtest': (1.9345790332489514, 0.38011193014359135, 2),
#    'params_ftest': (0.7617131750243451, 0.48409837563899916, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e2139d5250>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e90f70>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'GDP(亿元)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.4231  , p=0.0095  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=9.8269  , p=0.0017  , df=1
# likelihood ratio test: chi2=8.0612  , p=0.0045  , df=1
# parameter F test:         F=8.4231  , p=0.0095  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6862  , p=0.0499  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=9.8298  , p=0.0073  , df=2
# likelihood ratio test: chi2=7.9955  , p=0.0184  , df=2
# parameter F test:         F=3.6862  , p=0.0499  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (8.423093601741293, 0.009498981581317293, 18.0, 1),
#    'ssr_chi2test': (9.826942535364841, 0.0017197397848732236, 1),
#    'lrtest': (8.061199177926966, 0.004522324224186129, 1),
#    'params_ftest': (8.42309360174131, 0.009498981581317232, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ea0880>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e21351ee20>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (3.6861803259411143, 0.049870744881852766, 15.0, 2),
#    'ssr_chi2test': (9.829814202509638, 0.007336399403056066, 2),
#    'lrtest': (7.995521928170064, 0.018356694207025893, 2),
#    'params_ftest': (3.6861803259411166, 0.049870744881852704, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e215f9c190>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ea0be0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ '工业产值占比%','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0300  , p=0.8645  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=0.0350  , p=0.8516  , df=1
# likelihood ratio test: chi2=0.0349  , p=0.8517  , df=1
# parameter F test:         F=0.0300  , p=0.8645  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5673  , p=0.2409  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=4.1795  , p=0.1237  , df=2
# likelihood ratio test: chi2=3.7955  , p=0.1499  , df=2
# parameter F test:         F=1.5673  , p=0.2409  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (0.02998178801738122, 0.8644638027464536, 18.0, 1),
#    'ssr_chi2test': (0.03497875268694476, 0.8516401888458214, 1),
#    'lrtest': (0.034949653729782426, 0.8517011963562096, 1),
#    'params_ftest': (0.02998178801738496, 0.8644638027464492, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ebc070>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e21351e610>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.5673306331544905, 0.2409148571947114, 15.0, 2),
#    'ssr_chi2test': (4.179548355078642, 0.1237150703048181, 2),
#    'lrtest': (3.7954978601639198, 0.14990568788227385, 2),
#    'params_ftest': (1.5673306331544778, 0.2409148571947138, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ebcac0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e90580>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'per human capital (yuan/person)','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.4919  , p=0.0780  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=4.0739  , p=0.0435  , df=1
# likelihood ratio test: chi2=3.7234  , p=0.0537  , df=1
# parameter F test:         F=3.4919  , p=0.0780  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1519  , p=0.1508  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=5.7383  , p=0.0567  , df=2
# likelihood ratio test: chi2=5.0450  , p=0.0803  , df=2
# parameter F test:         F=2.1519  , p=0.1508  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (3.491938849309709, 0.07803166774046301, 18.0, 1),
#    'ssr_chi2test': (4.073928657527994, 0.043549874667848425, 1),
#    'lrtest': (3.7234295634795274, 0.05365406034507827, 1),
#    'params_ftest': (3.491938849309827, 0.07803166774045833, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20f79bf70>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20f737a60>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.151875377255567, 0.1507897017468899, 15.0, 2),
#    'ssr_chi2test': (5.738334339348179, 0.05674616683417688, 2),
#    'lrtest': (5.0449843107821835, 0.08025933856018312, 2),
#    'params_ftest': (2.151875377255468, 0.15078970174690154, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20f730820>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20c36caf0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'FDI（亿美元）','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.0183  , p=0.1725  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=2.3547  , p=0.1249  , df=1
# likelihood ratio test: chi2=2.2318  , p=0.1352  , df=1
# parameter F test:         F=2.0183  , p=0.1725  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1293  , p=0.3492  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=3.0115  , p=0.2218  , df=2
# likelihood ratio test: chi2=2.8053  , p=0.2459  , df=2
# parameter F test:         F=1.1293  , p=0.3492  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (2.018343771933607, 0.1725002103019197, 18.0, 1),
#    'ssr_chi2test': (2.354734400589208, 0.1249031568824436, 1),
#    'lrtest': (2.2318229617752507, 0.13519425602054347, 1),
#    'params_ftest': (2.018343771933605, 0.17250021030192023, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20f724d60>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ea0970>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (1.1293268073340472, 0.3492469319523668, 15.0, 2),
#    'ssr_chi2test': (3.0115381528907923, 0.22184661120320032, 2),
#    'lrtest': (2.805269508155554, 0.24594809676338153, 2),
#    'params_ftest': (1.129326807334041, 0.3492469319523691, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20f7b0fa0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ea0310>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
grangercausalitytests(data[[ 'coal consumpution growth ratio','CO2 emissions']], maxlag=2)
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9468  , p=0.3434  , df_denom=18, df_num=1
# ssr based chi2 test:   chi2=1.1045  , p=0.2933  , df=1
# likelihood ratio test: chi2=1.0765  , p=0.2995  , df=1
# parameter F test:         F=0.9468  , p=0.3434  , df_denom=18, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.8151  , p=0.0916  , df_denom=15, df_num=2
# ssr based chi2 test:   chi2=7.5069  , p=0.0234  , df=2
# likelihood ratio test: chi2=6.3741  , p=0.0413  , df=2
# parameter F test:         F=2.8151  , p=0.0916  , df_denom=15, df_num=2
# {1: ({'ssr_ftest': (0.9467546685195335, 0.3434420329097386, 18.0, 1),
#    'ssr_chi2test': (1.104547113272789, 0.2932703642512431, 1),
#    'lrtest': (1.0764789287301113, 0.29948658115130267, 1),
#    'params_ftest': (0.9467546685195388, 0.34344203290973807, 18.0, 1.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213ebc6a0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e2139e6d90>,
#    array([[0., 1., 0.]])]),
#  2: ({'ssr_ftest': (2.815077753963808, 0.0916042620663384, 15.0, 2),
#    'ssr_chi2test': (7.506874010570155, 0.023437053987832027, 2),
#    'lrtest': (6.374073278069318, 0.04129405900854011, 2),
#    'params_ftest': (2.815077753963866, 0.0916042620663344, 15.0, 2.0)},
#   [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e213e8d6a0>,
#    <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x1e20c37f8b0>,
#    array([[0., 0., 1., 0., 0.],
#           [0., 0., 0., 1., 0.]])])}

# %%
#主要看p值（第二列），所有的p小于0.05才能证明b对a有效

# number of lags (no zero) 1：当lags为1时的检测结果
# ssr based F test：残差平方和F检验
# ssr based chi2 test：残差平方和卡方检验
# likelihood ratio test：似然比检验结果
# parr F testamete：参数 F 检验结果

# %%
from statsmodels.tsa.stattools import adfuller
adf_seq = np.array(data['CO2 emissions'])
dftest = adfuller(adf_seq,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)
# Out:
# Test Statistic                -5.38870e+00
# p-value                        0.00000e+00
# #Lags Used                     9.00000e+00
# Number of Observations Used    1.20000e+01
# Critical Value (1%)           -4.13783e+00
# dtype: float64
# Test Statistic                -5.38870e+00
# p-value                        0.00000e+00
# #Lags Used                     9.00000e+00
# Number of Observations Used    1.20000e+01
# Critical Value (1%)           -4.13783e+00
# Critical Value (5%)           -3.15497e+00
# dtype: float64
# Test Statistic                -5.38870e+00
# p-value                        0.00000e+00
# #Lags Used                     9.00000e+00
# Number of Observations Used    1.20000e+01
# Critical Value (1%)           -4.13783e+00
# Critical Value (5%)           -3.15497e+00
# Critical Value (10%)          -2.71448e+00
# dtype: float64

# %% [markdown]
# # Test Statistic : T值，表示T统计量
#
# p-value： p值，表示T统计量对应的概率值
#
# Lags Used：表示延迟
#
# Number of Observations Used: 表示测试的次数
#
# Critical Value 1% : 表示t值下小于 – 4.938690 ， 则原假设发生的概率小于1%， 其它的数值以此类推。
#
# 其中t值和p值是最重要的，其实这两个值是等效的，既可以看t值也可以看p值。
#
# p值越小越好，要求小于给定的显著水平，p值小于0.05，等于0最好。
#
# t值，ADF值要小于t值，1%， 5%， 10% 的三个level，都是一个临界值，如果小于这个临界值，说明拒绝原假设。
#
# 其中，1% ： 严格拒绝原假设； 5%： 拒绝原假设； 10% 以此类推，程度越来越低。如果，ADF小于1% level， 说明严格拒绝原假设
